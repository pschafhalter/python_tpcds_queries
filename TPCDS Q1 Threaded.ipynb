# %% [markdown]
# # Questions/Thoughts
# - How to best structure the project? Code is growing fast
# - How important is presenting results cleanly?
#     - Could look around for better profiling and create graphs in matplotlib
#     - Is it valuable to spend time automating profiling using decorators
# - What's the bigger picture? How will this system fit into Pywren?
# - Is there a benchmark? What kind of performance am I comparing against? Spark
# - Is there a way to check correctness of the query results? Using Spark

# %%
import pandas as pd
import numpy as np
import queue
import cProfile
import multiprocessing as mp

# %%
NUM_THREADS = 4

# %%
# File I/O functions
def read_header(table_name):
    # TODO: read directly from schema
    with open("headers/" + table_name, "r") as f:
        result = f.read().split("\n")
        f.close()
        return result

def read_table(table_name):
    header = read_header(table_name)
    filename = "data/{table_name}.dat".format(table_name=table_name)
    table = pd.read_csv(filename, names=header, delimiter='|')
    table.tail()
    return table

def read_table_chunk(table_name, chunk_id, total_chunks):
    header = read_header(table_name)
    filename = "data/{table_name}_{chunk_id}_{total_chunks}.dat".format(table_name=table_name,
                                                                        chunk_id=chunk_id,
                                                                        total_chunks=total_chunks)
    table = pd.read_csv(filename, names=header, delimiter='|')
    table.tail()
    return table

def read_bucket(table_name, chunk_id, total_chunks, column, bucket_id, total_buckets):
    header = read_header(table_name)
    filename_template = "data/{name}_{chunk_id}_{total_chunks}_{column}_{bucket_id}_{total_buckets}.dat"
    filename = filename_template.format(name=table_name, chunk_id=chunk_id, total_chunks=total_chunks,
                                       column=column, bucket_id=bucket_id, total_buckets=total_buckets)
    table = pd.read_csv(filename, names=header, delimiter='|')
    table.tail()
    return table

def write_header(table_name, columns):
    with open("headers/" + table_name, "w") as f:
        f.write("\n".join(columns))
        f.close()

def write_table(table_name, table):
    write_header(table_name, table.columns)
    filename = "data/{table_name}.dat".format(table_name=table_name)
    table.to_csv(filename, sep='|', header=None)
    
def write_table_chunk(table_name, table, chunk_id, total_chunks):
    write_header(table_name, table.columns)
    filename = "data/{table_name}_{chunk_id}_{total_chunks}.dat".format(table_name=table_name,
                                                                        chunk_id=chunk_id,
                                                                        total_chunks=total_chunks)
    table.to_csv(filename, sep='|', header=None)
    
def write_buckets(buckets, table_name, chunk_id, total_chunks, column):
    total_buckets = len(buckets)
    assert total_buckets > 0, "There must be at least 1 bucket"
    write_header(table_name, buckets[0].columns)
    filename_template = "data/{name}_{chunk_id}_{total_chunks}_{column}_{bucket_id}_{total_buckets}.dat"
    for i, bucket in enumerate(buckets):
        filename = filename_template.format(name=table_name, chunk_id=chunk_id, column=column,
                                                 total_chunks=total_chunks, bucket_id=i + 1,
                                                 total_buckets=total_buckets)
        bucket.to_csv(filename, sep='|', header=None)

# %%
def join_on_column(A, B, a_column, b_column):
    """Merges 2 tables where a_column and b_column are equal.
    
    Assumes that a_column and b_column contain unique keys.
    This is *much* faster than filtered_cartesian product.
    However, it can be replaced with a map/reduce:
        1. map over rows of A
        2. select row with matching key in B
        3. return concatenation of row from A with row from B
        4. reduce list of concatenated rows by converting to dataframe
    
    Params:
        - A: a table (pandas dataframe object)
        - B: a table (pandas dataframe object)
        - a_column: string name of column of keys in A
        - b_column: string name of column of keys in B
    
    Returns:
        pandas dataframe
        
    Note:
        - The returned dataframe does not contain a column with the label
            b_column.
    """
    B_renamed  = B.rename(columns={b_column: a_column}, inplace=False)
    return pd.merge(A, B_renamed, on=a_column)

# %%
def filter_chunked_table(table_name, filtered_name, num_chunks, filter_fun):
    """Filters table in chunks.
    
    Args:
        filter_fun: takes a table chunk and returns a filtered table chunk
    """
    for i in range(num_chunks):
        chunk = read_table_chunk(table_name, i+1, num_chunks)
        chunk_filtered = filter_fun(chunk)
        write_table_chunk(filtered_name, chunk_filtered, i+1, num_chunks)

# %%
def assign_bucket_hash(item, total_buckets):
    return hash(item) % total_buckets

def assign_bucket_range(item, total_buckets):
    """Assigns item to a bucket associated to a particular range.
    Note: bucket ranges must be consistent across chunks.
    """
    raise NotImplementedError

# %%
# Modified this for multithreading
def split_chunk_into_buckets(i, table_name, column, total_chunks, assign_bucket_fn, total_buckets):
    """Splits a chunk into buckets and writes them
    """
    chunk = read_table_chunk(table_name, i, total_chunks)
    buckets_list = [list() for _ in range(total_buckets)]
    
    for idx, row in chunk.iterrows():
        bucket = assign_bucket_fn(row[column], total_buckets)
        buckets_list[bucket].append(row)
    buckets = [pd.DataFrame(rows, columns=chunk.columns) for rows in buckets_list]
        
    write_buckets(buckets, table_name, i, total_chunks, column)
    return True

def reduce_buckets_to_chunk(bucket_id, table_name, column, total_chunks, total_buckets, new_table_name):
    bucket_list = []
    for chunk_id in range(1, total_chunks + 1):
        bucket = read_bucket(table_name, chunk_id, total_chunks, column, bucket_id, total_buckets)
        bucket_list.append(bucket)
    chunk = pd.concat(bucket_list, ignore_index=True)
    write_table_chunk(new_table_name, chunk, bucket_id, total_buckets)

# %%
def split_table_into_buckets_threaded(table_name, column, total_chunks, assign_bucket_fn,
                                      total_buckets, num_threads=NUM_THREADS):
    # Is this the proper way, or is it better to modify split_chunk_into_buckets?
    args = [(i + 1, table_name, column, total_chunks, assign_bucket_fn, total_buckets)
            for i in range(total_buckets)]
    with mp.Pool(num_threads) as p:
        return all(p.starmap(split_chunk_into_buckets, args))
        
def merge_buckets_threaded(table_name, column, total_chunks, total_buckets,
                           new_table_name="", num_threads=NUM_THREADS):
    if not new_table_name:
        new_table_name = table_name
    args = [(i + 1, table_name, column, total_chunks, total_buckets, new_table_name)
           for i in range(total_buckets)]
    with mp.Pool(num_threads) as p:
        return all(p.starmap(reduce_buckets_to_chunk, args))

# %%
def join_buckets_on_column(a_name, a_column, b_name, b_column, bucket_id, total_buckets, out_name):
    a_bucket = read_table_chunk(a_name, bucket_id, total_buckets)
    b_bucket = read_table_chunk(b_name, bucket_id, total_buckets)
    joined_bucket = join_on_column(a_bucket, b_bucket, a_column, b_column)
    write_table_chunk(out_name, joined_bucket, bucket_id, total_buckets)
    return True

# %%
def join_on_column_threaded(a_name, a_column, a_total_chunks,
                               b_name, b_column, b_total_chunks,
                               out_name, total_buckets, num_threads=NUM_THREADS):
    # Split into buckets by hash
    split_table_into_buckets_threaded(a_name, a_column, a_total_chunks,
                                      assign_bucket_hash, total_buckets, num_threads)
    split_table_into_buckets_threaded(b_name, b_column, b_total_chunks,
                                      assign_bucket_hash, total_buckets, num_threads)
    # Merge buckets
    a_temp_name = a_name + "_hash_grouped"
    b_temp_name = b_name + "_hash_grouped"
    merge_buckets_threaded(a_name, a_column, a_total_chunks, total_buckets, a_temp_name, num_threads)
    merge_buckets_threaded(b_name, b_column, b_total_chunks, total_buckets, b_temp_name, num_threads)
    args = [(a_temp_name, a_column, b_temp_name, b_column, i + 1, total_buckets, out_name)
            for i in range(total_buckets)]
    with mp.Pool(num_threads) as p:
        return all(p.starmap(join_buckets_on_column, args))

# %%
def join_on_column_threaded_other(a_name, a_column, a_total_chunks,
                               b_name, b_column, b_total_chunks,
                               out_name, total_buckets, num_threads=NUM_THREADS):
    """Does not thread the joining of buckets. This is almost the same speed.
    Maybe due to I/O intensive operations and low numbers of buckets and data in join_buckets_on_column
    """
    # Split into buckets by hash
    split_table_into_buckets_threaded(a_name, a_column, a_total_chunks,
                                      assign_bucket_hash, total_buckets, num_threads)
    split_table_into_buckets_threaded(b_name, b_column, b_total_chunks,
                                      assign_bucket_hash, total_buckets, num_threads)
    # Merge buckets
    a_temp_name = a_name + "_hash_grouped"
    b_temp_name = b_name + "_hash_grouped"
    merge_buckets_threaded(a_name, a_column, a_total_chunks, total_buckets, a_temp_name, num_threads)
    merge_buckets_threaded(b_name, b_column, b_total_chunks, total_buckets, b_temp_name, num_threads)
    args = [(a_temp_name, a_column, b_temp_name, b_column, i + 1, total_buckets, out_name)
            for i in range(total_buckets)]
    for bucket_id in range(1, total_buckets + 1):
        # buckets are now chunks of the new table
        a_bucket = read_table_chunk(a_temp_name, bucket_id, total_buckets)
        b_bucket = read_table_chunk(b_temp_name, bucket_id, total_buckets)
        joined_bucket = join_on_column(a_bucket, b_bucket, a_column, b_column)
        write_table_chunk(out_name, joined_bucket, bucket_id, total_buckets)

# %%
# Filter date_dim
filter_chunked_table("date_dim", "date_dim_filtered", 3, lambda tbl: tbl[tbl["d_year"] == 2000])

# %%
# Using 2 threads
cProfile.run('join_on_column_threaded("date_dim_filtered", "d_date_sk", 3, '+
                          '"store_returns", "sr_returned_date_sk", 3,' +
                          '"ctr_joined", 3, 2)')
# Out:
#          4147 function calls in 43.788 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        45    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:996(_handle_fromlist)
#         2    0.000    0.000   35.309   17.654 <ipython-input-74-81de4cfdaee6>:1(split_table_into_buckets_threaded)
#         2    0.000    0.000    0.000    0.000 <ipython-input-74-81de4cfdaee6>:13(<listcomp>)
#         2    0.000    0.000    0.000    0.000 <ipython-input-74-81de4cfdaee6>:4(<listcomp>)
#         2    0.000    0.000    5.853    2.927 <ipython-input-74-81de4cfdaee6>:9(merge_buckets_threaded)
#         1    0.000    0.000   43.785   43.785 <ipython-input-82-5bd60ebc15df>:1(join_on_column_threaded)
#         1    0.000    0.000    0.000    0.000 <ipython-input-82-5bd60ebc15df>:14(<listcomp>)
#         1    0.001    0.001   43.787   43.787 <string>:1(<module>)
#        25    0.000    0.000    0.000    0.000 _weakrefset.py:38(_remove)
#        25    0.000    0.000    0.000    0.000 _weakrefset.py:81(add)
#        20    0.000    0.000    0.000    0.000 connection.py:117(__init__)
#        20    0.000    0.000    0.000    0.000 connection.py:130(__del__)
#         5    0.000    0.000    0.000    0.000 connection.py:134(_check_closed)
#         5    0.000    0.000    0.000    0.000 connection.py:142(_check_writable)
#         5    0.000    0.000    0.000    0.000 connection.py:181(send_bytes)
#        20    0.000    0.000    0.000    0.000 connection.py:360(_close)
#         5    0.000    0.000    0.000    0.000 connection.py:365(_send)
#         5    0.000    0.000    0.000    0.000 connection.py:390(_send_bytes)
#        10    0.000    0.000    0.000    0.000 connection.py:501(Pipe)
#        10    0.000    0.000    0.003    0.000 context.py:108(SimpleQueue)
#         5    0.000    0.000    0.056    0.011 context.py:113(Pool)
#        30    0.000    0.000    0.000    0.000 context.py:185(get_context)
#        20    0.000    0.000    0.000    0.000 context.py:195(get_start_method)
#         5    0.000    0.000    0.000    0.000 context.py:221(get_context)
#        10    0.001    0.000    0.043    0.004 context.py:264(_Popen)
#        20    0.000    0.000    0.003    0.000 context.py:63(Lock)
#        40    0.003    0.000    0.003    0.000 iostream.py:180(schedule)
#        20    0.001    0.000    0.011    0.001 iostream.py:312(flush)
#        40    0.000    0.000    0.000    0.000 iostream.py:89(_event_pipe)
#        10    0.000    0.000    0.001    0.000 pool.py:144(Process)
#         5    0.001    0.000    0.056    0.011 pool.py:147(__init__)
#         5    0.001    0.000    0.046    0.009 pool.py:219(_repopulate_pool)
#         5    0.000    0.000    0.003    0.001 pool.py:242(_setup_queues)
#         5    0.000    0.000   43.378    8.676 pool.py:262(starmap)
#         5    0.000    0.000    0.001    0.000 pool.py:335(_map_async)
#         5    0.000    0.000    0.350    0.070 pool.py:501(terminate)
#         5    0.000    0.000    0.309    0.062 pool.py:516(_help_stuff_finish)
#         5    0.001    0.000    0.350    0.070 pool.py:525(_terminate_pool)
#         5    0.000    0.000    0.000    0.000 pool.py:571(__enter__)
#         5    0.000    0.000    0.351    0.070 pool.py:574(__exit__)
#         5    0.000    0.000    0.000    0.000 pool.py:583(__init__)
#         5    0.000    0.000    0.000    0.000 pool.py:591(ready)
#         5    0.000    0.000   43.377    8.675 pool.py:598(wait)
#         5    0.000    0.000   43.377    8.675 pool.py:601(get)
#         5    0.000    0.000    0.000    0.000 pool.py:627(__init__)
#        10    0.001    0.000    0.042    0.004 popen_fork.py:16(__init__)
#        36    0.000    0.000    0.039    0.001 popen_fork.py:25(poll)
#         7    0.000    0.000    0.039    0.006 popen_fork.py:44(wait)
#        10    0.000    0.000    0.000    0.000 popen_fork.py:54(terminate)
#        10    0.001    0.000    0.031    0.003 popen_fork.py:64(_launch)
#        10    0.000    0.000    0.000    0.000 process.py:109(terminate)
#         7    0.000    0.000    0.039    0.006 process.py:115(join)
#        10    0.000    0.000    0.000    0.000 process.py:125(is_alive)
#        10    0.000    0.000    0.000    0.000 process.py:137(name)
#        10    0.000    0.000    0.000    0.000 process.py:141(name)
#        10    0.000    0.000    0.000    0.000 process.py:153(daemon)
#        10    0.000    0.000    0.000    0.000 process.py:172(exitcode)
#         7    0.000    0.000    0.000    0.000 process.py:181(ident)
#        20    0.000    0.000    0.000    0.000 process.py:35(current_process)
#        10    0.000    0.000    0.000    0.000 process.py:52(_cleanup)
#        10    0.001    0.000    0.001    0.000 process.py:71(__init__)
#        20    0.000    0.000    0.000    0.000 process.py:83(<genexpr>)
#        10    0.001    0.000    0.045    0.004 process.py:95(start)
#         5    0.000    0.000    0.000    0.000 queue.py:115(put)
#         5    0.000    0.000    0.000    0.000 queue.py:199(_init)
#         5    0.000    0.000    0.000    0.000 queue.py:206(_put)
#         5    0.000    0.000    0.000    0.000 queue.py:27(__init__)
#        10    0.000    0.000    0.003    0.000 queues.py:322(__init__)
#         5    0.000    0.000    0.001    0.000 queues.py:347(put)
#       160    0.000    0.000    0.000    0.000 random.py:229(_randbelow)
#       160    0.000    0.000    0.001    0.000 random.py:259(choice)
#         5    0.000    0.000    0.000    0.000 reduction.py:37(__init__)
#         5    0.000    0.000    0.000    0.000 reduction.py:47(dumps)
#        20    0.000    0.000    0.001    0.000 synchronize.py:115(_make_name)
#        20    0.000    0.000    0.002    0.000 synchronize.py:162(__init__)
#        20    0.001    0.000    0.002    0.000 synchronize.py:51(__init__)
#        20    0.000    0.000    0.000    0.000 synchronize.py:91(_make_methods)
#         5    0.000    0.000    0.000    0.000 synchronize.py:95(__enter__)
#         5    0.000    0.000    0.000    0.000 synchronize.py:98(__exit__)
#        20    0.000    0.000    0.000    0.000 tempfile.py:285(rng)
#        20    0.000    0.000    0.001    0.000 tempfile.py:296(__next__)
#        20    0.000    0.000    0.001    0.000 tempfile.py:299(<listcomp>)
#        15    0.000    0.000    0.000    0.000 threading.py:1022(join)
#        85    0.000    0.000    0.000    0.000 threading.py:1060(_wait_for_tstate_lock)
#        70    0.001    0.000    0.001    0.000 threading.py:1102(is_alive)
#        15    0.000    0.000    0.000    0.000 threading.py:1118(daemon)
#        15    0.000    0.000    0.000    0.000 threading.py:1134(daemon)
#        45    0.000    0.000    0.000    0.000 threading.py:1224(current_thread)
#        55    0.001    0.000    0.001    0.000 threading.py:213(__init__)
#        45    0.000    0.000    0.000    0.000 threading.py:237(__enter__)
#        45    0.000    0.000    0.000    0.000 threading.py:240(__exit__)
#        38    0.000    0.000    0.000    0.000 threading.py:246(_release_save)
#        38    0.000    0.000    0.000    0.000 threading.py:249(_acquire_restore)
#        43    0.000    0.000    0.000    0.000 threading.py:252(_is_owned)
#        38    0.000    0.000   43.386    1.142 threading.py:261(wait)
#         5    0.000    0.000    0.000    0.000 threading.py:332(notify)
#        40    0.000    0.000    0.001    0.000 threading.py:496(__init__)
#       120    0.000    0.000    0.000    0.000 threading.py:504(is_set)
#        40    0.000    0.000   43.386    1.085 threading.py:531(wait)
#        15    0.000    0.000    0.000    0.000 threading.py:725(_newname)
#        15    0.001    0.000    0.002    0.000 threading.py:755(__init__)
#        15    0.000    0.000    0.004    0.000 threading.py:826(start)
#        15    0.000    0.000    0.000    0.000 threading.py:964(_stop)
#        20    0.000    0.000    0.000    0.000 util.py:136(register_after_fork)
#        15    0.001    0.000    0.001    0.000 util.py:151(__init__)
#        15    0.000    0.000    0.351    0.023 util.py:167(__call__)
#        15    0.000    0.000    0.000    0.000 util.py:44(sub_debug)
#        82    0.000    0.000    0.000    0.000 util.py:48(debug)
#        20    0.000    0.000    0.000    0.000 weakref.py:109(remove)
#        20    0.000    0.000    0.000    0.000 weakref.py:165(__setitem__)
#        20    0.000    0.000    0.000    0.000 weakref.py:334(__new__)
#        20    0.000    0.000    0.000    0.000 weakref.py:339(__init__)
#        20    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x55d56fb57140}
#         5    0.000    0.000    0.000    0.000 {built-in method _struct.pack}
#        83    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#        45    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#        15    0.001    0.000    0.001    0.000 {built-in method _thread.start_new_thread}
#        20    0.000    0.000    0.000    0.000 {built-in method _weakref._remove_dead_weakref}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#         1    0.002    0.002   43.788   43.788 {built-in method builtins.exec}
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        60    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#       210    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#        70    0.000    0.000    0.001    0.000 {built-in method builtins.next}
#         9    0.000    0.000    0.000    0.000 {built-in method posix.WEXITSTATUS}
#         9    0.000    0.000    0.000    0.000 {built-in method posix.WIFEXITED}
#        10    0.000    0.000    0.000    0.000 {built-in method posix.WIFSIGNALED}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.WTERMSIG}
#        40    0.000    0.000    0.000    0.000 {built-in method posix.close}
#        10    0.028    0.003    0.028    0.003 {built-in method posix.fork}
#        87    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#        10    0.000    0.000    0.000    0.000 {built-in method posix.kill}
#        20    0.000    0.000    0.000    0.000 {built-in method posix.pipe}
#        40    0.000    0.000    0.000    0.000 {built-in method posix.urandom}
#        32    0.039    0.001    0.039    0.001 {built-in method posix.waitpid}
#         5    0.000    0.000    0.000    0.000 {built-in method posix.write}
#         5    0.000    0.000    0.000    0.000 {method '__enter__' of '_multiprocessing.SemLock' objects}
#        45    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         5    0.000    0.000    0.000    0.000 {method '__exit__' of '_multiprocessing.SemLock' objects}
#        45    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         5    0.309    0.062    0.309    0.062 {method 'acquire' of '_multiprocessing.SemLock' objects}
#       232   43.385    0.187   43.385    0.187 {method 'acquire' of '_thread.lock' objects}
#        35    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#        43    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        10    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#       160    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#        15    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        36    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#         5    0.000    0.000    0.000    0.000 {method 'dump' of '_pickle.Pickler' objects}
#        10    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         5    0.000    0.000    0.000    0.000 {method 'getbuffer' of '_io.BytesIO' objects}
#       248    0.000    0.000    0.000    0.000 {method 'getrandbits' of '_random.Random' objects}
#        30    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#        15    0.000    0.000    0.000    0.000 {method 'locked' of '_thread.lock' objects}
#        58    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         5    0.000    0.000    0.000    0.000 {method 'remove' of 'collections.deque' objects}
#        10    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}

# %%
# Using 4 threads
cProfile.run('join_on_column_threaded("date_dim_filtered", "d_date_sk", 3, '+
                          '"store_returns", "sr_returned_date_sk", 3,' +
                          '"ctr_joined", 3, 4)')
# Out:
#          5426 function calls in 32.952 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        55    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:996(_handle_fromlist)
#         2    0.000    0.000   26.429   13.215 <ipython-input-74-81de4cfdaee6>:1(split_table_into_buckets_threaded)
#         2    0.000    0.000    0.000    0.000 <ipython-input-74-81de4cfdaee6>:13(<listcomp>)
#         2    0.000    0.000    0.000    0.000 <ipython-input-74-81de4cfdaee6>:4(<listcomp>)
#         2    0.000    0.000    4.482    2.241 <ipython-input-74-81de4cfdaee6>:9(merge_buckets_threaded)
#         1    0.000    0.000   32.952   32.952 <ipython-input-82-5bd60ebc15df>:1(join_on_column_threaded)
#         1    0.000    0.000    0.000    0.000 <ipython-input-82-5bd60ebc15df>:14(<listcomp>)
#         1    0.000    0.000   32.952   32.952 <string>:1(<module>)
#        32    0.000    0.000    0.000    0.000 _weakrefset.py:38(_remove)
#        35    0.000    0.000    0.000    0.000 _weakrefset.py:81(add)
#        20    0.000    0.000    0.000    0.000 connection.py:117(__init__)
#        16    0.000    0.000    0.000    0.000 connection.py:130(__del__)
#         5    0.000    0.000    0.000    0.000 connection.py:134(_check_closed)
#         5    0.000    0.000    0.000    0.000 connection.py:142(_check_writable)
#         5    0.000    0.000    0.000    0.000 connection.py:181(send_bytes)
#        16    0.000    0.000    0.000    0.000 connection.py:360(_close)
#         5    0.000    0.000    0.000    0.000 connection.py:365(_send)
#         5    0.000    0.000    0.000    0.000 connection.py:390(_send_bytes)
#        10    0.000    0.000    0.000    0.000 connection.py:501(Pipe)
#        10    0.000    0.000    0.003    0.000 context.py:108(SimpleQueue)
#         5    0.000    0.000    0.124    0.025 context.py:113(Pool)
#        30    0.000    0.000    0.000    0.000 context.py:185(get_context)
#        20    0.000    0.000    0.000    0.000 context.py:195(get_start_method)
#         5    0.000    0.000    0.000    0.000 context.py:221(get_context)
#        20    0.001    0.000    0.102    0.005 context.py:264(_Popen)
#        20    0.000    0.000    0.002    0.000 context.py:63(Lock)
#        80    0.007    0.000    0.009    0.000 iostream.py:180(schedule)
#        40    0.001    0.000    0.027    0.001 iostream.py:312(flush)
#        80    0.000    0.000    0.000    0.000 iostream.py:89(_event_pipe)
#        20    0.000    0.000    0.003    0.000 pool.py:144(Process)
#         5    0.001    0.000    0.123    0.025 pool.py:147(__init__)
#         5    0.002    0.000    0.110    0.022 pool.py:219(_repopulate_pool)
#         5    0.000    0.000    0.003    0.001 pool.py:242(_setup_queues)
#         5    0.000    0.000   32.497    6.499 pool.py:262(starmap)
#         5    0.000    0.000    0.001    0.000 pool.py:335(_map_async)
#         5    0.000    0.000    0.332    0.066 pool.py:501(terminate)
#         5    0.000    0.000    0.279    0.056 pool.py:516(_help_stuff_finish)
#         5    0.001    0.000    0.331    0.066 pool.py:525(_terminate_pool)
#         5    0.000    0.000    0.000    0.000 pool.py:571(__enter__)
#         5    0.000    0.000    0.332    0.066 pool.py:574(__exit__)
#         5    0.000    0.000    0.000    0.000 pool.py:583(__init__)
#         5    0.000    0.000    0.000    0.000 pool.py:591(ready)
#         5    0.000    0.000   32.496    6.499 pool.py:598(wait)
#         5    0.000    0.000   32.496    6.499 pool.py:601(get)
#         5    0.000    0.000    0.000    0.000 pool.py:627(__init__)
#        20    0.001    0.000    0.100    0.005 popen_fork.py:16(__init__)
#        87    0.000    0.000    0.050    0.001 popen_fork.py:25(poll)
#         8    0.000    0.000    0.050    0.006 popen_fork.py:44(wait)
#        19    0.000    0.000    0.000    0.000 popen_fork.py:54(terminate)
#        20    0.003    0.000    0.072    0.004 popen_fork.py:64(_launch)
#        19    0.000    0.000    0.000    0.000 process.py:109(terminate)
#         8    0.000    0.000    0.050    0.006 process.py:115(join)
#        20    0.000    0.000    0.000    0.000 process.py:125(is_alive)
#        20    0.000    0.000    0.000    0.000 process.py:137(name)
#        20    0.000    0.000    0.000    0.000 process.py:141(name)
#        20    0.000    0.000    0.000    0.000 process.py:153(daemon)
#        20    0.000    0.000    0.000    0.000 process.py:172(exitcode)
#         8    0.000    0.000    0.000    0.000 process.py:181(ident)
#        20    0.000    0.000    0.000    0.000 process.py:35(current_process)
#        20    0.000    0.000    0.001    0.000 process.py:52(_cleanup)
#        20    0.002    0.000    0.002    0.000 process.py:71(__init__)
#        40    0.000    0.000    0.000    0.000 process.py:83(<genexpr>)
#        20    0.002    0.000    0.104    0.005 process.py:95(start)
#         5    0.000    0.000    0.000    0.000 queue.py:115(put)
#         5    0.000    0.000    0.000    0.000 queue.py:199(_init)
#         5    0.000    0.000    0.000    0.000 queue.py:206(_put)
#         5    0.000    0.000    0.000    0.000 queue.py:27(__init__)
#        10    0.000    0.000    0.003    0.000 queues.py:322(__init__)
#         5    0.000    0.000    0.001    0.000 queues.py:347(put)
#       160    0.000    0.000    0.000    0.000 random.py:229(_randbelow)
#       160    0.000    0.000    0.001    0.000 random.py:259(choice)
#         5    0.000    0.000    0.000    0.000 reduction.py:37(__init__)
#         5    0.000    0.000    0.000    0.000 reduction.py:47(dumps)
#        20    0.000    0.000    0.001    0.000 synchronize.py:115(_make_name)
#        20    0.000    0.000    0.002    0.000 synchronize.py:162(__init__)
#        20    0.001    0.000    0.002    0.000 synchronize.py:51(__init__)
#        20    0.000    0.000    0.000    0.000 synchronize.py:91(_make_methods)
#         5    0.000    0.000    0.000    0.000 synchronize.py:95(__enter__)
#         5    0.000    0.000    0.000    0.000 synchronize.py:98(__exit__)
#        20    0.000    0.000    0.000    0.000 tempfile.py:285(rng)
#        20    0.000    0.000    0.001    0.000 tempfile.py:296(__next__)
#        20    0.000    0.000    0.001    0.000 tempfile.py:299(<listcomp>)
#        15    0.000    0.000    0.000    0.000 threading.py:1022(join)
#       145    0.000    0.000    0.001    0.000 threading.py:1060(_wait_for_tstate_lock)
#       130    0.001    0.000    0.002    0.000 threading.py:1102(is_alive)
#        15    0.000    0.000    0.000    0.000 threading.py:1118(daemon)
#        15    0.000    0.000    0.000    0.000 threading.py:1134(daemon)
#        45    0.000    0.000    0.000    0.000 threading.py:1224(current_thread)
#        75    0.001    0.000    0.001    0.000 threading.py:213(__init__)
#        65    0.000    0.000    0.000    0.000 threading.py:237(__enter__)
#        65    0.000    0.000    0.000    0.000 threading.py:240(__exit__)
#        54    0.000    0.000    0.000    0.000 threading.py:246(_release_save)
#        54    0.000    0.000    0.000    0.000 threading.py:249(_acquire_restore)
#        59    0.000    0.000    0.000    0.000 threading.py:252(_is_owned)
#        54    0.001    0.000   32.516    0.602 threading.py:261(wait)
#         5    0.000    0.000    0.000    0.000 threading.py:332(notify)
#        60    0.001    0.000    0.002    0.000 threading.py:496(__init__)
#       180    0.000    0.000    0.000    0.000 threading.py:504(is_set)
#        60    0.001    0.000   32.517    0.542 threading.py:531(wait)
#        15    0.000    0.000    0.000    0.000 threading.py:725(_newname)
#        15    0.001    0.000    0.002    0.000 threading.py:755(__init__)
#        15    0.000    0.000    0.008    0.001 threading.py:826(start)
#        15    0.000    0.000    0.000    0.000 threading.py:964(_stop)
#        20    0.000    0.000    0.000    0.000 util.py:136(register_after_fork)
#        25    0.002    0.000    0.002    0.000 util.py:151(__init__)
#        22    0.000    0.000    0.332    0.015 util.py:167(__call__)
#        22    0.000    0.000    0.000    0.000 util.py:44(sub_debug)
#        93    0.000    0.000    0.000    0.000 util.py:48(debug)
#        16    0.000    0.000    0.000    0.000 weakref.py:109(remove)
#        20    0.000    0.000    0.000    0.000 weakref.py:165(__setitem__)
#        20    0.000    0.000    0.000    0.000 weakref.py:334(__new__)
#        20    0.000    0.000    0.000    0.000 weakref.py:339(__init__)
#        20    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x55d56fb57140}
#         5    0.000    0.000    0.000    0.000 {built-in method _struct.pack}
#       119    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#        45    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#        15    0.001    0.000    0.001    0.000 {built-in method _thread.start_new_thread}
#        16    0.000    0.000    0.000    0.000 {built-in method _weakref._remove_dead_weakref}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#         1    0.000    0.000   32.952   32.952 {built-in method builtins.exec}
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        70    0.001    0.000    0.001    0.000 {built-in method builtins.hasattr}
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#       210    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#        90    0.000    0.000    0.001    0.000 {built-in method builtins.next}
#        17    0.000    0.000    0.000    0.000 {built-in method posix.WEXITSTATUS}
#        17    0.000    0.000    0.000    0.000 {built-in method posix.WIFEXITED}
#        20    0.000    0.000    0.000    0.000 {built-in method posix.WIFSIGNALED}
#         3    0.000    0.000    0.000    0.000 {built-in method posix.WTERMSIG}
#        53    0.000    0.000    0.000    0.000 {built-in method posix.close}
#        20    0.066    0.003    0.066    0.003 {built-in method posix.fork}
#       135    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#        19    0.000    0.000    0.000    0.000 {built-in method posix.kill}
#        30    0.001    0.000    0.001    0.000 {built-in method posix.pipe}
#        80    0.001    0.000    0.001    0.000 {built-in method posix.urandom}
#        77    0.050    0.001    0.050    0.001 {built-in method posix.waitpid}
#         5    0.000    0.000    0.000    0.000 {built-in method posix.write}
#         5    0.000    0.000    0.000    0.000 {method '__enter__' of '_multiprocessing.SemLock' objects}
#        65    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         5    0.000    0.000    0.000    0.000 {method '__exit__' of '_multiprocessing.SemLock' objects}
#        65    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         5    0.279    0.056    0.279    0.056 {method 'acquire' of '_multiprocessing.SemLock' objects}
#       356   32.516    0.091   32.516    0.091 {method 'acquire' of '_thread.lock' objects}
#        55    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#        59    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        20    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#       160    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#        25    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        49    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#         5    0.000    0.000    0.000    0.000 {method 'dump' of '_pickle.Pickler' objects}
#        20    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         5    0.000    0.000    0.000    0.000 {method 'getbuffer' of '_io.BytesIO' objects}
#       267    0.000    0.000    0.000    0.000 {method 'getrandbits' of '_random.Random' objects}
#        40    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#        15    0.000    0.000    0.000    0.000 {method 'locked' of '_thread.lock' objects}
#        74    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         5    0.000    0.000    0.000    0.000 {method 'remove' of 'collections.deque' objects}
#        20    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}

# %%
# Using 6 threads
cProfile.run('join_on_column_threaded("date_dim_filtered", "d_date_sk", 3, '+
                          '"store_returns", "sr_returned_date_sk", 3,' +
                          '"ctr_joined", 3, 6)')
# Out:
#          6789 function calls in 34.137 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        65    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:996(_handle_fromlist)
#         2    0.000    0.000   26.663   13.332 <ipython-input-74-81de4cfdaee6>:1(split_table_into_buckets_threaded)
#         2    0.000    0.000    0.000    0.000 <ipython-input-74-81de4cfdaee6>:13(<listcomp>)
#         2    0.000    0.000    0.000    0.000 <ipython-input-74-81de4cfdaee6>:4(<listcomp>)
#         2    0.000    0.000    5.009    2.505 <ipython-input-74-81de4cfdaee6>:9(merge_buckets_threaded)
#         1    0.000    0.000   34.137   34.137 <ipython-input-82-5bd60ebc15df>:1(join_on_column_threaded)
#         1    0.000    0.000    0.000    0.000 <ipython-input-82-5bd60ebc15df>:14(<listcomp>)
#         1    0.000    0.000   34.137   34.137 <string>:1(<module>)
#        43    0.000    0.000    0.000    0.000 _weakrefset.py:38(_remove)
#        45    0.001    0.000    0.001    0.000 _weakrefset.py:81(add)
#        20    0.000    0.000    0.000    0.000 connection.py:117(__init__)
#        20    0.000    0.000    0.000    0.000 connection.py:130(__del__)
#         5    0.000    0.000    0.000    0.000 connection.py:134(_check_closed)
#         5    0.000    0.000    0.000    0.000 connection.py:142(_check_writable)
#         5    0.000    0.000    0.000    0.000 connection.py:181(send_bytes)
#        20    0.000    0.000    0.000    0.000 connection.py:360(_close)
#         5    0.000    0.000    0.000    0.000 connection.py:365(_send)
#         5    0.000    0.000    0.000    0.000 connection.py:390(_send_bytes)
#        10    0.000    0.000    0.002    0.000 connection.py:501(Pipe)
#        10    0.000    0.000    0.006    0.001 context.py:108(SimpleQueue)
#         5    0.000    0.000    0.177    0.035 context.py:113(Pool)
#        30    0.000    0.000    0.000    0.000 context.py:185(get_context)
#        20    0.000    0.000    0.000    0.000 context.py:195(get_start_method)
#         5    0.000    0.000    0.000    0.000 context.py:221(get_context)
#        30    0.002    0.000    0.146    0.005 context.py:264(_Popen)
#        20    0.000    0.000    0.005    0.000 context.py:63(Lock)
#       120    0.008    0.000    0.010    0.000 iostream.py:180(schedule)
#        60    0.002    0.000    0.037    0.001 iostream.py:312(flush)
#       120    0.000    0.000    0.000    0.000 iostream.py:89(_event_pipe)
#        30    0.001    0.000    0.005    0.000 pool.py:144(Process)
#         5    0.001    0.000    0.176    0.035 pool.py:147(__init__)
#         5    0.004    0.001    0.161    0.032 pool.py:219(_repopulate_pool)
#         5    0.000    0.000    0.006    0.001 pool.py:242(_setup_queues)
#         5    0.000    0.000   33.691    6.738 pool.py:262(starmap)
#         5    0.000    0.000    0.001    0.000 pool.py:335(_map_async)
#         5    0.000    0.000    0.269    0.054 pool.py:501(terminate)
#         5    0.000    0.000    0.223    0.045 pool.py:516(_help_stuff_finish)
#         5    0.000    0.000    0.269    0.054 pool.py:525(_terminate_pool)
#         5    0.000    0.000    0.000    0.000 pool.py:571(__enter__)
#         5    0.000    0.000    0.269    0.054 pool.py:574(__exit__)
#         5    0.000    0.000    0.000    0.000 pool.py:583(__init__)
#         5    0.000    0.000    0.000    0.000 pool.py:591(ready)
#         5    0.000    0.000   33.690    6.738 pool.py:598(wait)
#         5    0.000    0.000   33.690    6.738 pool.py:601(get)
#         5    0.000    0.000    0.000    0.000 pool.py:627(__init__)
#        30    0.002    0.000    0.143    0.005 popen_fork.py:16(__init__)
#       163    0.001    0.000    0.044    0.000 popen_fork.py:25(poll)
#         5    0.000    0.000    0.043    0.009 popen_fork.py:44(wait)
#        14    0.000    0.000    0.000    0.000 popen_fork.py:54(terminate)
#        30    0.005    0.000    0.105    0.003 popen_fork.py:64(_launch)
#        14    0.000    0.000    0.000    0.000 process.py:109(terminate)
#         5    0.000    0.000    0.043    0.009 process.py:115(join)
#        30    0.000    0.000    0.000    0.000 process.py:125(is_alive)
#        30    0.000    0.000    0.000    0.000 process.py:137(name)
#        30    0.000    0.000    0.000    0.000 process.py:141(name)
#        30    0.000    0.000    0.000    0.000 process.py:153(daemon)
#        30    0.000    0.000    0.000    0.000 process.py:172(exitcode)
#         5    0.000    0.000    0.000    0.000 process.py:181(ident)
#        20    0.000    0.000    0.000    0.000 process.py:35(current_process)
#        30    0.001    0.000    0.002    0.000 process.py:52(_cleanup)
#        30    0.003    0.000    0.004    0.000 process.py:71(__init__)
#        60    0.000    0.000    0.000    0.000 process.py:83(<genexpr>)
#        30    0.004    0.000    0.152    0.005 process.py:95(start)
#         5    0.000    0.000    0.000    0.000 queue.py:115(put)
#         5    0.000    0.000    0.000    0.000 queue.py:199(_init)
#         5    0.000    0.000    0.000    0.000 queue.py:206(_put)
#         5    0.000    0.000    0.000    0.000 queue.py:27(__init__)
#        10    0.000    0.000    0.006    0.001 queues.py:322(__init__)
#         5    0.000    0.000    0.001    0.000 queues.py:347(put)
#       160    0.000    0.000    0.000    0.000 random.py:229(_randbelow)
#       160    0.000    0.000    0.001    0.000 random.py:259(choice)
#         5    0.000    0.000    0.000    0.000 reduction.py:37(__init__)
#         5    0.000    0.000    0.000    0.000 reduction.py:47(dumps)
#        20    0.000    0.000    0.001    0.000 synchronize.py:115(_make_name)
#        20    0.000    0.000    0.004    0.000 synchronize.py:162(__init__)
#        20    0.003    0.000    0.004    0.000 synchronize.py:51(__init__)
#        20    0.000    0.000    0.000    0.000 synchronize.py:91(_make_methods)
#         5    0.000    0.000    0.000    0.000 synchronize.py:95(__enter__)
#         5    0.000    0.000    0.000    0.000 synchronize.py:98(__exit__)
#        20    0.000    0.000    0.000    0.000 tempfile.py:285(rng)
#        20    0.000    0.000    0.001    0.000 tempfile.py:296(__next__)
#        20    0.000    0.000    0.001    0.000 tempfile.py:299(<listcomp>)
#        15    0.000    0.000    0.000    0.000 threading.py:1022(join)
#       205    0.001    0.000    0.001    0.000 threading.py:1060(_wait_for_tstate_lock)
#       190    0.001    0.000    0.002    0.000 threading.py:1102(is_alive)
#        15    0.000    0.000    0.000    0.000 threading.py:1118(daemon)
#        15    0.000    0.000    0.000    0.000 threading.py:1134(daemon)
#        45    0.000    0.000    0.000    0.000 threading.py:1224(current_thread)
#        95    0.002    0.000    0.002    0.000 threading.py:213(__init__)
#        85    0.000    0.000    0.000    0.000 threading.py:237(__enter__)
#        85    0.000    0.000    0.000    0.000 threading.py:240(__exit__)
#        75    0.000    0.000    0.000    0.000 threading.py:246(_release_save)
#        75    0.000    0.000    0.000    0.000 threading.py:249(_acquire_restore)
#        80    0.000    0.000    0.000    0.000 threading.py:252(_is_owned)
#        75    0.001    0.000   33.713    0.450 threading.py:261(wait)
#         5    0.000    0.000    0.000    0.000 threading.py:332(notify)
#        80    0.001    0.000    0.003    0.000 threading.py:496(__init__)
#       240    0.000    0.000    0.000    0.000 threading.py:504(is_set)
#        80    0.001    0.000   33.715    0.421 threading.py:531(wait)
#        15    0.000    0.000    0.000    0.000 threading.py:725(_newname)
#        15    0.001    0.000    0.002    0.000 threading.py:755(__init__)
#        15    0.000    0.000    0.005    0.000 threading.py:826(start)
#        15    0.000    0.000    0.000    0.000 threading.py:964(_stop)
#        20    0.000    0.000    0.000    0.000 util.py:136(register_after_fork)
#        35    0.004    0.000    0.004    0.000 util.py:151(__init__)
#        33    0.000    0.000    0.269    0.008 util.py:167(__call__)
#        33    0.000    0.000    0.000    0.000 util.py:44(sub_debug)
#       100    0.000    0.000    0.000    0.000 util.py:48(debug)
#        20    0.000    0.000    0.000    0.000 weakref.py:109(remove)
#        20    0.000    0.000    0.000    0.000 weakref.py:165(__setitem__)
#        20    0.000    0.000    0.000    0.000 weakref.py:334(__new__)
#        20    0.000    0.000    0.000    0.000 weakref.py:339(__init__)
#        20    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x55d56fb57140}
#         5    0.000    0.000    0.000    0.000 {built-in method _struct.pack}
#       160    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#        45    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#        15    0.000    0.000    0.000    0.000 {built-in method _thread.start_new_thread}
#        20    0.000    0.000    0.000    0.000 {built-in method _weakref._remove_dead_weakref}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#         1    0.000    0.000   34.137   34.137 {built-in method builtins.exec}
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        80    0.001    0.000    0.001    0.000 {built-in method builtins.hasattr}
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#        30    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#       210    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#       110    0.000    0.000    0.001    0.000 {built-in method builtins.next}
#        28    0.000    0.000    0.000    0.000 {built-in method posix.WEXITSTATUS}
#        28    0.000    0.000    0.000    0.000 {built-in method posix.WIFEXITED}
#        30    0.000    0.000    0.000    0.000 {built-in method posix.WIFSIGNALED}
#         2    0.000    0.000    0.000    0.000 {built-in method posix.WTERMSIG}
#        78    0.001    0.000    0.001    0.000 {built-in method posix.close}
#        30    0.095    0.003    0.095    0.003 {built-in method posix.fork}
#       183    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#        14    0.000    0.000    0.000    0.000 {built-in method posix.kill}
#        40    0.002    0.000    0.002    0.000 {built-in method posix.pipe}
#       120    0.001    0.000    0.001    0.000 {built-in method posix.urandom}
#       124    0.044    0.000    0.044    0.000 {built-in method posix.waitpid}
#         5    0.000    0.000    0.000    0.000 {built-in method posix.write}
#         5    0.000    0.000    0.000    0.000 {method '__enter__' of '_multiprocessing.SemLock' objects}
#        85    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         5    0.000    0.000    0.000    0.000 {method '__exit__' of '_multiprocessing.SemLock' objects}
#        85    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         5    0.223    0.045    0.223    0.045 {method 'acquire' of '_multiprocessing.SemLock' objects}
#       500   33.712    0.067   33.712    0.067 {method 'acquire' of '_thread.lock' objects}
#        75    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#        80    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        30    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#       160    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#        35    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        71    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#         5    0.000    0.000    0.000    0.000 {method 'dump' of '_pickle.Pickler' objects}
#        30    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         5    0.000    0.000    0.000    0.000 {method 'getbuffer' of '_io.BytesIO' objects}
#       278    0.000    0.000    0.000    0.000 {method 'getrandbits' of '_random.Random' objects}
#        50    0.000    0.000    0.001    0.000 {method 'join' of 'str' objects}
#        15    0.000    0.000    0.000    0.000 {method 'locked' of '_thread.lock' objects}
#        95    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         5    0.000    0.000    0.000    0.000 {method 'remove' of 'collections.deque' objects}
#        30    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}

# %%
# Using 8 threads
cProfile.run('join_on_column_threaded("date_dim_filtered", "d_date_sk", 3, '+
                          '"store_returns", "sr_returned_date_sk", 3,' +
                          '"ctr_joined", 3, 8)')
# Out:
#          8237 function calls in 32.415 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        75    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:996(_handle_fromlist)
#         2    0.000    0.000   25.909   12.955 <ipython-input-74-81de4cfdaee6>:1(split_table_into_buckets_threaded)
#         2    0.000    0.000    0.000    0.000 <ipython-input-74-81de4cfdaee6>:13(<listcomp>)
#         2    0.000    0.000    0.000    0.000 <ipython-input-74-81de4cfdaee6>:4(<listcomp>)
#         2    0.000    0.000    4.427    2.214 <ipython-input-74-81de4cfdaee6>:9(merge_buckets_threaded)
#         1    0.000    0.000   32.415   32.415 <ipython-input-82-5bd60ebc15df>:1(join_on_column_threaded)
#         1    0.000    0.000    0.000    0.000 <ipython-input-82-5bd60ebc15df>:14(<listcomp>)
#         1    0.000    0.000   32.415   32.415 <string>:1(<module>)
#        53    0.000    0.000    0.000    0.000 _weakrefset.py:38(_remove)
#        55    0.001    0.000    0.001    0.000 _weakrefset.py:81(add)
#        20    0.000    0.000    0.000    0.000 connection.py:117(__init__)
#        20    0.000    0.000    0.000    0.000 connection.py:130(__del__)
#         5    0.000    0.000    0.000    0.000 connection.py:134(_check_closed)
#         5    0.000    0.000    0.000    0.000 connection.py:142(_check_writable)
#         5    0.000    0.000    0.000    0.000 connection.py:181(send_bytes)
#        20    0.000    0.000    0.000    0.000 connection.py:360(_close)
#         5    0.000    0.000    0.000    0.000 connection.py:365(_send)
#         5    0.000    0.000    0.000    0.000 connection.py:390(_send_bytes)
#        10    0.000    0.000    0.001    0.000 connection.py:501(Pipe)
#        10    0.000    0.000    0.004    0.000 context.py:108(SimpleQueue)
#         5    0.000    0.000    0.249    0.050 context.py:113(Pool)
#        30    0.000    0.000    0.000    0.000 context.py:185(get_context)
#        20    0.000    0.000    0.000    0.000 context.py:195(get_start_method)
#         5    0.000    0.000    0.000    0.000 context.py:221(get_context)
#        40    0.004    0.000    0.216    0.005 context.py:264(_Popen)
#        20    0.000    0.000    0.003    0.000 context.py:63(Lock)
#       160    0.010    0.000    0.012    0.000 iostream.py:180(schedule)
#        80    0.003    0.000    0.055    0.001 iostream.py:312(flush)
#       160    0.001    0.000    0.001    0.000 iostream.py:89(_event_pipe)
#        40    0.001    0.000    0.007    0.000 pool.py:144(Process)
#         5    0.001    0.000    0.248    0.050 pool.py:147(__init__)
#         5    0.005    0.001    0.236    0.047 pool.py:219(_repopulate_pool)
#         5    0.000    0.000    0.004    0.001 pool.py:242(_setup_queues)
#         5    0.000    0.000   31.825    6.365 pool.py:262(starmap)
#         5    0.000    0.000    0.001    0.000 pool.py:335(_map_async)
#         5    0.000    0.000    0.340    0.068 pool.py:501(terminate)
#         5    0.000    0.000    0.298    0.060 pool.py:516(_help_stuff_finish)
#         5    0.000    0.000    0.340    0.068 pool.py:525(_terminate_pool)
#         5    0.000    0.000    0.000    0.000 pool.py:571(__enter__)
#         5    0.000    0.000    0.340    0.068 pool.py:574(__exit__)
#         5    0.000    0.000    0.000    0.000 pool.py:583(__init__)
#         5    0.000    0.000    0.000    0.000 pool.py:591(ready)
#         5    0.000    0.000   31.824    6.365 pool.py:598(wait)
#         5    0.000    0.000   31.825    6.365 pool.py:601(get)
#         5    0.000    0.000    0.000    0.000 pool.py:627(__init__)
#        40    0.003    0.000    0.211    0.005 popen_fork.py:16(__init__)
#       258    0.001    0.000    0.041    0.000 popen_fork.py:25(poll)
#         8    0.000    0.000    0.039    0.005 popen_fork.py:44(wait)
#        20    0.000    0.000    0.000    0.000 popen_fork.py:54(terminate)
#        40    0.007    0.000    0.152    0.004 popen_fork.py:64(_launch)
#        20    0.000    0.000    0.000    0.000 process.py:109(terminate)
#         8    0.000    0.000    0.039    0.005 process.py:115(join)
#        40    0.000    0.000    0.000    0.000 process.py:125(is_alive)
#        40    0.000    0.000    0.000    0.000 process.py:137(name)
#        40    0.000    0.000    0.000    0.000 process.py:141(name)
#        40    0.000    0.000    0.000    0.000 process.py:153(daemon)
#        40    0.000    0.000    0.001    0.000 process.py:172(exitcode)
#         8    0.000    0.000    0.000    0.000 process.py:181(ident)
#        20    0.000    0.000    0.000    0.000 process.py:35(current_process)
#        40    0.001    0.000    0.002    0.000 process.py:52(_cleanup)
#        40    0.004    0.000    0.006    0.000 process.py:71(__init__)
#        80    0.000    0.000    0.000    0.000 process.py:83(<genexpr>)
#        40    0.003    0.000    0.223    0.006 process.py:95(start)
#         5    0.000    0.000    0.000    0.000 queue.py:115(put)
#         5    0.000    0.000    0.000    0.000 queue.py:199(_init)
#         5    0.000    0.000    0.000    0.000 queue.py:206(_put)
#         5    0.000    0.000    0.000    0.000 queue.py:27(__init__)
#        10    0.000    0.000    0.004    0.000 queues.py:322(__init__)
#         5    0.000    0.000    0.001    0.000 queues.py:347(put)
#       160    0.000    0.000    0.000    0.000 random.py:229(_randbelow)
#       160    0.000    0.000    0.001    0.000 random.py:259(choice)
#         5    0.000    0.000    0.000    0.000 reduction.py:37(__init__)
#         5    0.000    0.000    0.000    0.000 reduction.py:47(dumps)
#        20    0.000    0.000    0.001    0.000 synchronize.py:115(_make_name)
#        20    0.000    0.000    0.003    0.000 synchronize.py:162(__init__)
#        20    0.001    0.000    0.003    0.000 synchronize.py:51(__init__)
#        20    0.000    0.000    0.000    0.000 synchronize.py:91(_make_methods)
#         5    0.000    0.000    0.000    0.000 synchronize.py:95(__enter__)
#         5    0.000    0.000    0.000    0.000 synchronize.py:98(__exit__)
#        20    0.000    0.000    0.000    0.000 tempfile.py:285(rng)
#        20    0.000    0.000    0.001    0.000 tempfile.py:296(__next__)
#        20    0.000    0.000    0.001    0.000 tempfile.py:299(<listcomp>)
#        15    0.000    0.000    0.000    0.000 threading.py:1022(join)
#       265    0.001    0.000    0.001    0.000 threading.py:1060(_wait_for_tstate_lock)
#       250    0.002    0.000    0.003    0.000 threading.py:1102(is_alive)
#        15    0.000    0.000    0.000    0.000 threading.py:1118(daemon)
#        15    0.000    0.000    0.000    0.000 threading.py:1134(daemon)
#        45    0.000    0.000    0.000    0.000 threading.py:1224(current_thread)
#       115    0.002    0.000    0.002    0.000 threading.py:213(__init__)
#       105    0.000    0.000    0.000    0.000 threading.py:237(__enter__)
#       105    0.000    0.000    0.000    0.000 threading.py:240(__exit__)
#        97    0.000    0.000    0.000    0.000 threading.py:246(_release_save)
#        97    0.000    0.000    0.000    0.000 threading.py:249(_acquire_restore)
#       102    0.000    0.000    0.000    0.000 threading.py:252(_is_owned)
#        97    0.001    0.000   31.863    0.328 threading.py:261(wait)
#         5    0.000    0.000    0.000    0.000 threading.py:332(notify)
#       100    0.001    0.000    0.004    0.000 threading.py:496(__init__)
#       300    0.000    0.000    0.000    0.000 threading.py:504(is_set)
#       100    0.001    0.000   31.864    0.319 threading.py:531(wait)
#        15    0.000    0.000    0.000    0.000 threading.py:725(_newname)
#        15    0.001    0.000    0.002    0.000 threading.py:755(__init__)
#        15    0.000    0.000    0.006    0.000 threading.py:826(start)
#        15    0.000    0.000    0.000    0.000 threading.py:964(_stop)
#        20    0.000    0.000    0.000    0.000 util.py:136(register_after_fork)
#        45    0.005    0.000    0.005    0.000 util.py:151(__init__)
#        43    0.000    0.000    0.340    0.008 util.py:167(__call__)
#        43    0.000    0.000    0.000    0.000 util.py:44(sub_debug)
#       113    0.000    0.000    0.000    0.000 util.py:48(debug)
#        20    0.000    0.000    0.000    0.000 weakref.py:109(remove)
#        20    0.000    0.000    0.000    0.000 weakref.py:165(__setitem__)
#        20    0.000    0.000    0.000    0.000 weakref.py:334(__new__)
#        20    0.000    0.000    0.000    0.000 weakref.py:339(__init__)
#        20    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x55d56fb57140}
#         5    0.000    0.000    0.000    0.000 {built-in method _struct.pack}
#       202    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#        45    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#        15    0.001    0.000    0.001    0.000 {built-in method _thread.start_new_thread}
#        20    0.000    0.000    0.000    0.000 {built-in method _weakref._remove_dead_weakref}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#         1    0.000    0.000   32.415   32.415 {built-in method builtins.exec}
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        90    0.001    0.000    0.001    0.000 {built-in method builtins.hasattr}
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#        40    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#       210    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#       130    0.000    0.000    0.001    0.000 {built-in method builtins.next}
#        36    0.000    0.000    0.000    0.000 {built-in method posix.WEXITSTATUS}
#        36    0.000    0.000    0.000    0.000 {built-in method posix.WIFEXITED}
#        40    0.000    0.000    0.000    0.000 {built-in method posix.WIFSIGNALED}
#         4    0.000    0.000    0.000    0.000 {built-in method posix.WTERMSIG}
#        98    0.001    0.000    0.001    0.000 {built-in method posix.close}
#        40    0.139    0.003    0.139    0.003 {built-in method posix.fork}
#       236    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#        20    0.000    0.000    0.000    0.000 {built-in method posix.kill}
#        50    0.001    0.000    0.001    0.000 {built-in method posix.pipe}
#       160    0.001    0.000    0.001    0.000 {built-in method posix.urandom}
#       208    0.040    0.000    0.040    0.000 {built-in method posix.waitpid}
#         5    0.000    0.000    0.000    0.000 {built-in method posix.write}
#         5    0.000    0.000    0.000    0.000 {method '__enter__' of '_multiprocessing.SemLock' objects}
#       105    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         5    0.000    0.000    0.000    0.000 {method '__exit__' of '_multiprocessing.SemLock' objects}
#       105    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         5    0.298    0.060    0.298    0.060 {method 'acquire' of '_multiprocessing.SemLock' objects}
#       648   31.861    0.049   31.861    0.049 {method 'acquire' of '_thread.lock' objects}
#        95    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#       102    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        40    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#       160    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#        45    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        91    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#         5    0.000    0.000    0.000    0.000 {method 'dump' of '_pickle.Pickler' objects}
#        40    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         5    0.000    0.000    0.000    0.000 {method 'getbuffer' of '_io.BytesIO' objects}
#       274    0.000    0.000    0.000    0.000 {method 'getrandbits' of '_random.Random' objects}
#        60    0.001    0.000    0.001    0.000 {method 'join' of 'str' objects}
#        15    0.000    0.000    0.000    0.000 {method 'locked' of '_thread.lock' objects}
#       117    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         5    0.000    0.000    0.000    0.000 {method 'remove' of 'collections.deque' objects}
#        40    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}

# %% [markdown]
# # Analysis
# Laptop CPU (Asus UX305FA) has 2 CPUs, 4 total hyper threads. Therefore, there's a natural speedup up to 4 threads. However, these results aren't reliable because we split into 3 buckets. Need bigger data and more chunks/buckets for more accurate results.
