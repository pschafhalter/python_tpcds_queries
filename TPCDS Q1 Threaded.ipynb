# %% [markdown]
# # Questions/Thoughts

# %%
import pandas as pd
import numpy as np
import queue
import cProfile
import multiprocessing as mp
from tools import table_io

# %%
NUM_THREADS = 4

# %%
def join_on_column(A, B, a_column, b_column):
    """Merges 2 tables where a_column and b_column are equal.
    
    Assumes that a_column and b_column contain unique keys.
    This is *much* faster than filtered_cartesian product.
    However, it can be replaced with a map/reduce:
        1. map over rows of A
        2. select row with matching key in B
        3. return concatenation of row from A with row from B
        4. reduce list of concatenated rows by converting to dataframe
    
    Params:
        - A: a table (pandas dataframe object)
        - B: a table (pandas dataframe object)
        - a_column: string name of column of keys in A
        - b_column: string name of column of keys in B
    
    Returns:
        pandas dataframe
        
    Note:
        - The returned dataframe does not contain a column with the label
            b_column.
    """
    B_renamed  = B.rename(columns={b_column: a_column}, inplace=False)
    return pd.merge(A, B_renamed, on=a_column)

# %%
def filter_chunked_table(table_name, filtered_name, num_chunks, filter_fun):
    """Filters table in chunks.
    
    Args:
        filter_fun: takes a table chunk and returns a filtered table chunk
    """
    for i in range(num_chunks):
        chunk = table_io.read_table_chunk(table_name, i+1, num_chunks)
        chunk_filtered = filter_fun(chunk)
        table_io.write_table_chunk(filtered_name, chunk_filtered, i+1, num_chunks)

# %%
def assign_bucket_hash(item, total_buckets):
    return hash(item) % total_buckets

def assign_bucket_range(item, total_buckets):
    """Assigns item to a bucket associated to a particular range.
    Note: bucket ranges must be consistent across chunks.
    """
    raise NotImplementedError

# %%
# Modified this for multithreading
def split_chunk_into_buckets(i, table_name, column, total_chunks, assign_bucket_fn, total_buckets):
    """Splits a chunk into buckets and writes them
    """
    chunk = table_io.read_table_chunk(table_name, i, total_chunks)
    buckets_list = [list() for _ in range(total_buckets)]
    
    for idx, row in chunk.iterrows():
        bucket = assign_bucket_fn(row[column], total_buckets)
        buckets_list[bucket].append(row)
    buckets = [pd.DataFrame(rows, columns=chunk.columns) for rows in buckets_list]
        
    table_io.write_buckets(buckets, table_name, i, total_chunks, column)
    return True

def reduce_buckets_to_chunk(bucket_id, table_name, column, total_chunks, total_buckets, new_table_name):
    bucket_list = []
    for chunk_id in range(1, total_chunks + 1):
        bucket = table_io.read_bucket(table_name, chunk_id, total_chunks, column, bucket_id, total_buckets)
        bucket_list.append(bucket)
    chunk = pd.concat(bucket_list, ignore_index=True)
    table_io.write_table_chunk(new_table_name, chunk, bucket_id, total_buckets)

# %%
def split_table_into_buckets_threaded(table_name, column, total_chunks, assign_bucket_fn,
                                      total_buckets, num_threads=NUM_THREADS):
    # Is this the proper way, or is it better to modify split_chunk_into_buckets?
    args = [(i + 1, table_name, column, total_chunks, assign_bucket_fn, total_buckets)
            for i in range(total_buckets)]
    with mp.Pool(num_threads) as p:
        return all(p.starmap(split_chunk_into_buckets, args))
        
def merge_buckets_threaded(table_name, column, total_chunks, total_buckets,
                           new_table_name="", num_threads=NUM_THREADS):
    if not new_table_name:
        new_table_name = table_name
    args = [(i + 1, table_name, column, total_chunks, total_buckets, new_table_name)
           for i in range(total_buckets)]
    with mp.Pool(num_threads) as p:
        return all(p.starmap(reduce_buckets_to_chunk, args))

# %%
def join_buckets_on_column(a_name, a_column, b_name, b_column, bucket_id, total_buckets, out_name):
    a_bucket = table_io.read_table_chunk(a_name, bucket_id, total_buckets)
    b_bucket = table_io.read_table_chunk(b_name, bucket_id, total_buckets)
    joined_bucket = join_on_column(a_bucket, b_bucket, a_column, b_column)
    table_io.write_table_chunk(out_name, joined_bucket, bucket_id, total_buckets)
    return True

# %%
def join_on_column_threaded(a_name, a_column, a_total_chunks,
                               b_name, b_column, b_total_chunks,
                               out_name, total_buckets, num_threads=NUM_THREADS):
    # Split into buckets by hash
    split_table_into_buckets_threaded(a_name, a_column, a_total_chunks,
                                      assign_bucket_hash, total_buckets, num_threads)
    split_table_into_buckets_threaded(b_name, b_column, b_total_chunks,
                                      assign_bucket_hash, total_buckets, num_threads)
    # Merge buckets
    a_temp_name = a_name + "_hash_grouped"
    b_temp_name = b_name + "_hash_grouped"
    merge_buckets_threaded(a_name, a_column, a_total_chunks, total_buckets, a_temp_name, num_threads)
    merge_buckets_threaded(b_name, b_column, b_total_chunks, total_buckets, b_temp_name, num_threads)
    args = [(a_temp_name, a_column, b_temp_name, b_column, i + 1, total_buckets, out_name)
            for i in range(total_buckets)]
    with mp.Pool(num_threads) as p:
        return all(p.starmap(join_buckets_on_column, args))

# %% [markdown]
# # Try using varying numbers of threads with tables split into 20 chunks

# %%
# Filter date_dim
NUM_CHUNKS = 20
NUM_BUCKETS = 20
filter_chunked_table("date_dim", "date_dim_filtered", NUM_CHUNKS, lambda tbl: tbl[tbl["d_year"] == 2000])

# %%
exec_template = 'join_on_column_threaded("date_dim_filtered", "d_date_sk", {num_chunks}, ' + \
                          '"store_returns", "sr_returned_date_sk", {num_chunks},' + \
                          '"ctr_joined", {num_buckets}, {num_threads})'

# %%
# Using 1 thread
cProfile.run(exec_template.format(num_chunks=NUM_CHUNKS, num_buckets=NUM_BUCKETS, num_threads=1))
# Out:
#          3636 function calls in 48.340 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        40    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:416(parent)
#        40    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:997(_handle_fromlist)
#         1    0.001    0.001   48.339   48.339 <ipython-input-14-5bd60ebc15df>:1(join_on_column_threaded)
#         1    0.000    0.000    0.000    0.000 <ipython-input-14-5bd60ebc15df>:14(<listcomp>)
#         2    0.000    0.000   36.488   18.244 <ipython-input-7-81de4cfdaee6>:1(split_table_into_buckets_threaded)
#         2    0.000    0.000    0.000    0.000 <ipython-input-7-81de4cfdaee6>:13(<listcomp>)
#         2    0.000    0.000    0.000    0.000 <ipython-input-7-81de4cfdaee6>:4(<listcomp>)
#         2    0.000    0.000   10.839    5.419 <ipython-input-7-81de4cfdaee6>:9(merge_buckets_threaded)
#         1    0.000    0.000   48.340   48.340 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <string>:12(__new__)
#        20    0.000    0.000    0.000    0.000 _weakrefset.py:38(_remove)
#        20    0.000    0.000    0.000    0.000 _weakrefset.py:81(add)
#        20    0.000    0.000    0.000    0.000 connection.py:117(__init__)
#        20    0.000    0.000    0.000    0.000 connection.py:130(__del__)
#         7    0.000    0.000    0.000    0.000 connection.py:134(_check_closed)
#         1    0.000    0.000    0.000    0.000 connection.py:138(_check_readable)
#         5    0.000    0.000    0.000    0.000 connection.py:142(_check_writable)
#         1    0.000    0.000    0.000    0.000 connection.py:168(fileno)
#         5    0.000    0.000    0.000    0.000 connection.py:181(send_bytes)
#         1    0.000    0.000    0.000    0.000 connection.py:253(poll)
#        20    0.000    0.000    0.000    0.000 connection.py:360(_close)
#         5    0.000    0.000    0.000    0.000 connection.py:365(_send)
#         5    0.000    0.000    0.000    0.000 connection.py:390(_send_bytes)
#         1    0.000    0.000    0.000    0.000 connection.py:413(_poll)
#        10    0.000    0.000    0.000    0.000 connection.py:501(Pipe)
#         1    0.000    0.000    0.000    0.000 connection.py:897(wait)
#        10    0.000    0.000    0.004    0.000 context.py:109(SimpleQueue)
#         5    0.000    0.000    0.025    0.005 context.py:114(Pool)
#        30    0.000    0.000    0.000    0.000 context.py:186(get_context)
#        20    0.000    0.000    0.000    0.000 context.py:196(get_start_method)
#         5    0.000    0.000    0.000    0.000 context.py:232(get_context)
#         5    0.000    0.000    0.013    0.003 context.py:274(_Popen)
#        20    0.000    0.000    0.004    0.000 context.py:64(Lock)
#        20    0.001    0.000    0.001    0.000 iostream.py:180(schedule)
#        10    0.000    0.000    0.004    0.000 iostream.py:311(flush)
#        20    0.000    0.000    0.000    0.000 iostream.py:87(_event_pipe)
#         5    0.000    0.000    0.000    0.000 pool.py:150(Process)
#         5    0.001    0.000    0.025    0.005 pool.py:153(__init__)
#         5    0.000    0.000    0.014    0.003 pool.py:225(_repopulate_pool)
#         5    0.000    0.000    0.004    0.001 pool.py:248(_setup_queues)
#         5    0.000    0.000   48.153    9.631 pool.py:268(starmap)
#         5    0.000    0.000    0.001    0.000 pool.py:368(_map_async)
#         5    0.000    0.000    0.160    0.032 pool.py:537(terminate)
#         5    0.000    0.000    0.140    0.028 pool.py:552(_help_stuff_finish)
#         5    0.000    0.000    0.159    0.032 pool.py:561(_terminate_pool)
#         5    0.000    0.000    0.000    0.000 pool.py:607(__enter__)
#         5    0.000    0.000    0.160    0.032 pool.py:610(__exit__)
#         5    0.000    0.000    0.000    0.000 pool.py:619(__init__)
#         5    0.000    0.000    0.000    0.000 pool.py:627(ready)
#         5    0.000    0.000   48.153    9.631 pool.py:634(wait)
#         5    0.000    0.000   48.153    9.631 pool.py:637(get)
#         5    0.000    0.000    0.000    0.000 pool.py:663(__init__)
#         5    0.000    0.000    0.013    0.003 popen_fork.py:16(__init__)
#        15    0.000    0.000    0.018    0.001 popen_fork.py:25(poll)
#         5    0.000    0.000    0.018    0.004 popen_fork.py:44(wait)
#         5    0.000    0.000    0.000    0.000 popen_fork.py:54(terminate)
#         5    0.001    0.000    0.009    0.002 popen_fork.py:64(_launch)
#         5    0.000    0.000    0.000    0.000 process.py:112(terminate)
#         5    0.000    0.000    0.018    0.004 process.py:118(join)
#         5    0.000    0.000    0.000    0.000 process.py:128(is_alive)
#         5    0.000    0.000    0.000    0.000 process.py:146(name)
#         5    0.000    0.000    0.000    0.000 process.py:150(name)
#         5    0.000    0.000    0.000    0.000 process.py:162(daemon)
#         5    0.000    0.000    0.000    0.000 process.py:181(exitcode)
#         5    0.000    0.000    0.000    0.000 process.py:190(ident)
#        20    0.000    0.000    0.000    0.000 process.py:35(current_process)
#         5    0.000    0.000    0.000    0.000 process.py:52(_cleanup)
#         5    0.000    0.000    0.000    0.000 process.py:71(__init__)
#        10    0.000    0.000    0.000    0.000 process.py:83(<genexpr>)
#         5    0.000    0.000    0.014    0.003 process.py:95(start)
#         5    0.000    0.000    0.000    0.000 queue.py:115(put)
#         5    0.000    0.000    0.000    0.000 queue.py:199(_init)
#         5    0.000    0.000    0.000    0.000 queue.py:206(_put)
#         5    0.000    0.000    0.000    0.000 queue.py:27(__init__)
#        10    0.000    0.000    0.004    0.000 queues.py:313(__init__)
#         5    0.000    0.000    0.000    0.000 queues.py:339(put)
#       160    0.000    0.000    0.001    0.000 random.py:222(_randbelow)
#       160    0.000    0.000    0.001    0.000 random.py:252(choice)
#         5    0.000    0.000    0.000    0.000 reduction.py:38(__init__)
#         5    0.000    0.000    0.000    0.000 reduction.py:48(dumps)
#         1    0.000    0.000    0.000    0.000 selectors.py:198(__enter__)
#         1    0.000    0.000    0.000    0.000 selectors.py:20(_fileobj_to_fd)
#         1    0.000    0.000    0.000    0.000 selectors.py:201(__exit__)
#         1    0.000    0.000    0.000    0.000 selectors.py:208(__init__)
#         1    0.000    0.000    0.000    0.000 selectors.py:214(_fileobj_lookup)
#         1    0.000    0.000    0.000    0.000 selectors.py:233(register)
#         1    0.000    0.000    0.000    0.000 selectors.py:268(close)
#         1    0.000    0.000    0.000    0.000 selectors.py:346(__init__)
#         1    0.000    0.000    0.000    0.000 selectors.py:350(register)
#         1    0.000    0.000    0.000    0.000 selectors.py:365(select)
#         1    0.000    0.000    0.000    0.000 selectors.py:62(__init__)
#        20    0.000    0.000    0.002    0.000 synchronize.py:115(_make_name)
#        20    0.000    0.000    0.003    0.000 synchronize.py:162(__init__)
#        20    0.001    0.000    0.003    0.000 synchronize.py:51(__init__)
#        20    0.000    0.000    0.000    0.000 synchronize.py:91(_make_methods)
#         5    0.000    0.000    0.000    0.000 synchronize.py:95(__enter__)
#         5    0.000    0.000    0.000    0.000 synchronize.py:98(__exit__)
#        20    0.000    0.000    0.000    0.000 tempfile.py:285(rng)
#        20    0.000    0.000    0.001    0.000 tempfile.py:296(__next__)
#        20    0.000    0.000    0.001    0.000 tempfile.py:299(<listcomp>)
#        15    0.000    0.000    0.000    0.000 threading.py:1024(join)
#        55    0.000    0.000    0.000    0.000 threading.py:1062(_wait_for_tstate_lock)
#        40    0.000    0.000    0.000    0.000 threading.py:1104(is_alive)
#        15    0.000    0.000    0.000    0.000 threading.py:1120(daemon)
#        15    0.000    0.000    0.000    0.000 threading.py:1136(daemon)
#        45    0.000    0.000    0.000    0.000 threading.py:1230(current_thread)
#        45    0.001    0.000    0.001    0.000 threading.py:215(__init__)
#        35    0.000    0.000    0.000    0.000 threading.py:239(__enter__)
#        35    0.000    0.000    0.000    0.000 threading.py:242(__exit__)
#        30    0.000    0.000    0.000    0.000 threading.py:248(_release_save)
#        30    0.000    0.000    0.000    0.000 threading.py:251(_acquire_restore)
#        35    0.000    0.000    0.000    0.000 threading.py:254(_is_owned)
#        30    0.000    0.000   48.157    1.605 threading.py:263(wait)
#         5    0.000    0.000    0.000    0.000 threading.py:334(notify)
#        30    0.000    0.000    0.001    0.000 threading.py:498(__init__)
#        90    0.000    0.000    0.000    0.000 threading.py:506(is_set)
#        30    0.000    0.000   48.158    1.605 threading.py:533(wait)
#        15    0.000    0.000    0.000    0.000 threading.py:727(_newname)
#        15    0.001    0.000    0.001    0.000 threading.py:757(__init__)
#        15    0.000    0.000    0.004    0.000 threading.py:828(start)
#        15    0.000    0.000    0.000    0.000 threading.py:966(_stop)
#        20    0.000    0.000    0.000    0.000 util.py:136(register_after_fork)
#        10    0.000    0.000    0.000    0.000 util.py:151(__init__)
#        10    0.000    0.000    0.160    0.016 util.py:167(__call__)
#        10    0.000    0.000    0.000    0.000 util.py:44(sub_debug)
#        75    0.000    0.000    0.000    0.000 util.py:48(debug)
#        20    0.000    0.000    0.000    0.000 weakref.py:109(remove)
#        20    0.000    0.000    0.000    0.000 weakref.py:165(__setitem__)
#        20    0.000    0.000    0.000    0.000 weakref.py:334(__new__)
#        20    0.000    0.000    0.000    0.000 weakref.py:339(__init__)
#        21    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x9e3d20}
#         5    0.000    0.000    0.000    0.000 {built-in method _struct.pack}
#        65    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#        45    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#        15    0.001    0.000    0.001    0.000 {built-in method _thread.start_new_thread}
#        20    0.000    0.000    0.000    0.000 {built-in method _weakref._remove_dead_weakref}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#         1    0.000    0.000   48.340   48.340 {built-in method builtins.exec}
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        55    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#       210    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#        60    0.000    0.000    0.001    0.000 {built-in method builtins.next}
#         5    0.000    0.000    0.000    0.000 {built-in method posix.WEXITSTATUS}
#         5    0.000    0.000    0.000    0.000 {built-in method posix.WIFEXITED}
#         5    0.000    0.000    0.000    0.000 {built-in method posix.WIFSIGNALED}
#        30    0.000    0.000    0.000    0.000 {built-in method posix.close}
#         5    0.008    0.002    0.008    0.002 {built-in method posix.fork}
#        60    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         5    0.000    0.000    0.000    0.000 {built-in method posix.kill}
#        15    0.000    0.000    0.000    0.000 {built-in method posix.pipe}
#        20    0.000    0.000    0.000    0.000 {built-in method posix.urandom}
#        15    0.018    0.001    0.018    0.001 {built-in method posix.waitpid}
#         5    0.000    0.000    0.000    0.000 {built-in method posix.write}
#         1    0.000    0.000    0.000    0.000 {built-in method select.poll}
#         2    0.000    0.000    0.000    0.000 {built-in method time.time}
#         5    0.000    0.000    0.000    0.000 {method '__enter__' of '_multiprocessing.SemLock' objects}
#        35    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         5    0.000    0.000    0.000    0.000 {method '__exit__' of '_multiprocessing.SemLock' objects}
#        35    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         5    0.140    0.028    0.140    0.028 {method 'acquire' of '_multiprocessing.SemLock' objects}
#       171   48.157    0.282   48.157    0.282 {method 'acquire' of '_thread.lock' objects}
#        25    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#        35    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         5    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#       160    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#         1    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#        10    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        25    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#         5    0.000    0.000    0.000    0.000 {method 'dump' of '_pickle.Pickler' objects}
#         5    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         5    0.000    0.000    0.000    0.000 {method 'getbuffer' of '_io.BytesIO' objects}
#       280    0.000    0.000    0.000    0.000 {method 'getrandbits' of '_random.Random' objects}
#        25    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#        15    0.000    0.000    0.000    0.000 {method 'locked' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'poll' of 'select.poll' objects}
#         1    0.000    0.000    0.000    0.000 {method 'register' of 'select.poll' objects}
#        50    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         5    0.000    0.000    0.000    0.000 {method 'remove' of 'collections.deque' objects}
#         5    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#        40    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}

# %%
# Using 2 threads
cProfile.run(exec_template.format(num_chunks=NUM_CHUNKS, num_buckets=NUM_BUCKETS, num_threads=2))
# Out:
#          4267 function calls in 27.244 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        45    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:416(parent)
#        45    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:997(_handle_fromlist)
#         1    0.001    0.001   27.244   27.244 <ipython-input-14-5bd60ebc15df>:1(join_on_column_threaded)
#         1    0.000    0.000    0.000    0.000 <ipython-input-14-5bd60ebc15df>:14(<listcomp>)
#         2    0.000    0.000   20.382   10.191 <ipython-input-7-81de4cfdaee6>:1(split_table_into_buckets_threaded)
#         2    0.000    0.000    0.000    0.000 <ipython-input-7-81de4cfdaee6>:13(<listcomp>)
#         2    0.000    0.000    0.000    0.000 <ipython-input-7-81de4cfdaee6>:4(<listcomp>)
#         2    0.000    0.000    6.245    3.123 <ipython-input-7-81de4cfdaee6>:9(merge_buckets_threaded)
#         1    0.000    0.000   27.244   27.244 <string>:1(<module>)
#        25    0.000    0.000    0.000    0.000 _weakrefset.py:38(_remove)
#        25    0.000    0.000    0.000    0.000 _weakrefset.py:81(add)
#        20    0.000    0.000    0.000    0.000 connection.py:117(__init__)
#        20    0.000    0.000    0.000    0.000 connection.py:130(__del__)
#         5    0.000    0.000    0.000    0.000 connection.py:134(_check_closed)
#         5    0.000    0.000    0.000    0.000 connection.py:142(_check_writable)
#         5    0.000    0.000    0.000    0.000 connection.py:181(send_bytes)
#        20    0.000    0.000    0.000    0.000 connection.py:360(_close)
#         5    0.000    0.000    0.000    0.000 connection.py:365(_send)
#         5    0.000    0.000    0.000    0.000 connection.py:390(_send_bytes)
#        10    0.000    0.000    0.000    0.000 connection.py:501(Pipe)
#        10    0.000    0.000    0.004    0.000 context.py:109(SimpleQueue)
#         5    0.000    0.000    0.047    0.009 context.py:114(Pool)
#        30    0.000    0.000    0.000    0.000 context.py:186(get_context)
#        20    0.000    0.000    0.000    0.000 context.py:196(get_start_method)
#         5    0.000    0.000    0.000    0.000 context.py:232(get_context)
#        10    0.000    0.000    0.032    0.003 context.py:274(_Popen)
#        20    0.000    0.000    0.004    0.000 context.py:64(Lock)
#        40    0.001    0.000    0.002    0.000 iostream.py:180(schedule)
#        20    0.000    0.000    0.009    0.000 iostream.py:311(flush)
#        40    0.000    0.000    0.000    0.000 iostream.py:87(_event_pipe)
#        10    0.000    0.000    0.001    0.000 pool.py:150(Process)
#         5    0.001    0.000    0.047    0.009 pool.py:153(__init__)
#         5    0.001    0.000    0.034    0.007 pool.py:225(_repopulate_pool)
#         5    0.000    0.000    0.004    0.001 pool.py:248(_setup_queues)
#         5    0.000    0.000   26.845    5.369 pool.py:268(starmap)
#         5    0.000    0.000    0.001    0.000 pool.py:368(_map_async)
#         5    0.000    0.000    0.351    0.070 pool.py:537(terminate)
#         5    0.000    0.000    0.326    0.065 pool.py:552(_help_stuff_finish)
#         5    0.000    0.000    0.351    0.070 pool.py:561(_terminate_pool)
#         5    0.000    0.000    0.000    0.000 pool.py:607(__enter__)
#         5    0.000    0.000    0.351    0.070 pool.py:610(__exit__)
#         5    0.000    0.000    0.000    0.000 pool.py:619(__init__)
#         5    0.000    0.000    0.000    0.000 pool.py:627(ready)
#         5    0.000    0.000   26.844    5.369 pool.py:634(wait)
#         5    0.000    0.000   26.844    5.369 pool.py:637(get)
#         5    0.000    0.000    0.000    0.000 pool.py:663(__init__)
#        10    0.000    0.000    0.032    0.003 popen_fork.py:16(__init__)
#        30    0.000    0.000    0.023    0.001 popen_fork.py:25(poll)
#         5    0.000    0.000    0.023    0.005 popen_fork.py:44(wait)
#        10    0.000    0.000    0.000    0.000 popen_fork.py:54(terminate)
#        10    0.001    0.000    0.022    0.002 popen_fork.py:64(_launch)
#        10    0.000    0.000    0.000    0.000 process.py:112(terminate)
#         5    0.000    0.000    0.023    0.005 process.py:118(join)
#        10    0.000    0.000    0.000    0.000 process.py:128(is_alive)
#        10    0.000    0.000    0.000    0.000 process.py:146(name)
#        10    0.000    0.000    0.000    0.000 process.py:150(name)
#        10    0.000    0.000    0.000    0.000 process.py:162(daemon)
#        10    0.000    0.000    0.000    0.000 process.py:181(exitcode)
#         5    0.000    0.000    0.000    0.000 process.py:190(ident)
#        20    0.000    0.000    0.000    0.000 process.py:35(current_process)
#        10    0.000    0.000    0.000    0.000 process.py:52(_cleanup)
#        10    0.000    0.000    0.001    0.000 process.py:71(__init__)
#        20    0.000    0.000    0.000    0.000 process.py:83(<genexpr>)
#        10    0.001    0.000    0.033    0.003 process.py:95(start)
#         5    0.000    0.000    0.000    0.000 queue.py:115(put)
#         5    0.000    0.000    0.000    0.000 queue.py:199(_init)
#         5    0.000    0.000    0.000    0.000 queue.py:206(_put)
#         5    0.000    0.000    0.000    0.000 queue.py:27(__init__)
#        10    0.000    0.000    0.004    0.000 queues.py:313(__init__)
#         5    0.000    0.000    0.000    0.000 queues.py:339(put)
#       160    0.000    0.000    0.001    0.000 random.py:222(_randbelow)
#       160    0.000    0.000    0.001    0.000 random.py:252(choice)
#         5    0.000    0.000    0.000    0.000 reduction.py:38(__init__)
#         5    0.000    0.000    0.000    0.000 reduction.py:48(dumps)
#        20    0.000    0.000    0.002    0.000 synchronize.py:115(_make_name)
#        20    0.000    0.000    0.003    0.000 synchronize.py:162(__init__)
#        20    0.001    0.000    0.003    0.000 synchronize.py:51(__init__)
#        20    0.000    0.000    0.000    0.000 synchronize.py:91(_make_methods)
#         5    0.000    0.000    0.000    0.000 synchronize.py:95(__enter__)
#         5    0.000    0.000    0.000    0.000 synchronize.py:98(__exit__)
#        20    0.000    0.000    0.000    0.000 tempfile.py:285(rng)
#        20    0.000    0.000    0.001    0.000 tempfile.py:296(__next__)
#        20    0.000    0.000    0.001    0.000 tempfile.py:299(<listcomp>)
#        15    0.000    0.000    0.000    0.000 threading.py:1024(join)
#        85    0.000    0.000    0.000    0.000 threading.py:1062(_wait_for_tstate_lock)
#        70    0.000    0.000    0.001    0.000 threading.py:1104(is_alive)
#        15    0.000    0.000    0.000    0.000 threading.py:1120(daemon)
#        15    0.000    0.000    0.000    0.000 threading.py:1136(daemon)
#        45    0.000    0.000    0.000    0.000 threading.py:1230(current_thread)
#        55    0.001    0.000    0.001    0.000 threading.py:215(__init__)
#        45    0.000    0.000    0.000    0.000 threading.py:239(__enter__)
#        45    0.000    0.000    0.000    0.000 threading.py:242(__exit__)
#        40    0.000    0.000    0.000    0.000 threading.py:248(_release_save)
#        40    0.000    0.000    0.000    0.000 threading.py:251(_acquire_restore)
#        45    0.000    0.000    0.000    0.000 threading.py:254(_is_owned)
#        40    0.000    0.000   26.854    0.671 threading.py:263(wait)
#         5    0.000    0.000    0.000    0.000 threading.py:334(notify)
#        40    0.000    0.000    0.001    0.000 threading.py:498(__init__)
#       120    0.000    0.000    0.000    0.000 threading.py:506(is_set)
#        40    0.000    0.000   26.855    0.671 threading.py:533(wait)
#        15    0.000    0.000    0.000    0.000 threading.py:727(_newname)
#        15    0.001    0.000    0.001    0.000 threading.py:757(__init__)
#        15    0.000    0.000    0.005    0.000 threading.py:828(start)
#        15    0.000    0.000    0.000    0.000 threading.py:966(_stop)
#        20    0.000    0.000    0.000    0.000 util.py:136(register_after_fork)
#        15    0.001    0.000    0.001    0.000 util.py:151(__init__)
#        15    0.000    0.000    0.351    0.023 util.py:167(__call__)
#        15    0.000    0.000    0.000    0.000 util.py:44(sub_debug)
#        80    0.000    0.000    0.000    0.000 util.py:48(debug)
#        20    0.000    0.000    0.000    0.000 weakref.py:109(remove)
#        20    0.000    0.000    0.000    0.000 weakref.py:165(__setitem__)
#        20    0.000    0.000    0.000    0.000 weakref.py:334(__new__)
#        20    0.000    0.000    0.000    0.000 weakref.py:339(__init__)
#        20    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x9e3d20}
#         5    0.000    0.000    0.000    0.000 {built-in method _struct.pack}
#        85    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#        45    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#        15    0.001    0.000    0.001    0.000 {built-in method _thread.start_new_thread}
#        20    0.000    0.000    0.000    0.000 {built-in method _weakref._remove_dead_weakref}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#         1    0.000    0.000   27.244   27.244 {built-in method builtins.exec}
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        60    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#       210    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#        70    0.000    0.000    0.002    0.000 {built-in method builtins.next}
#        10    0.000    0.000    0.000    0.000 {built-in method posix.WEXITSTATUS}
#        10    0.000    0.000    0.000    0.000 {built-in method posix.WIFEXITED}
#        10    0.000    0.000    0.000    0.000 {built-in method posix.WIFSIGNALED}
#        40    0.000    0.000    0.000    0.000 {built-in method posix.close}
#        10    0.020    0.002    0.020    0.002 {built-in method posix.fork}
#        85    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#        10    0.000    0.000    0.000    0.000 {built-in method posix.kill}
#        20    0.000    0.000    0.000    0.000 {built-in method posix.pipe}
#        40    0.001    0.000    0.001    0.000 {built-in method posix.urandom}
#        30    0.023    0.001    0.023    0.001 {built-in method posix.waitpid}
#         5    0.000    0.000    0.000    0.000 {built-in method posix.write}
#         5    0.000    0.000    0.000    0.000 {method '__enter__' of '_multiprocessing.SemLock' objects}
#        45    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         5    0.000    0.000    0.000    0.000 {method '__exit__' of '_multiprocessing.SemLock' objects}
#        45    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         5    0.326    0.065    0.326    0.065 {method 'acquire' of '_multiprocessing.SemLock' objects}
#       240   26.853    0.112   26.853    0.112 {method 'acquire' of '_thread.lock' objects}
#        35    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#        45    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        10    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#       160    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#        15    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        35    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#         5    0.000    0.000    0.000    0.000 {method 'dump' of '_pickle.Pickler' objects}
#        10    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         5    0.000    0.000    0.000    0.000 {method 'getbuffer' of '_io.BytesIO' objects}
#       274    0.000    0.000    0.000    0.000 {method 'getrandbits' of '_random.Random' objects}
#        30    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#        15    0.000    0.000    0.000    0.000 {method 'locked' of '_thread.lock' objects}
#        60    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         5    0.000    0.000    0.000    0.000 {method 'remove' of 'collections.deque' objects}
#        10    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#        45    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}

# %%
# Using 4 threads
cProfile.run(exec_template.format(num_chunks=NUM_CHUNKS, num_buckets=NUM_BUCKETS, num_threads=4))
# Out:
#          5641 function calls in 15.538 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        55    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:416(parent)
#        55    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:997(_handle_fromlist)
#         1    0.001    0.001   15.538   15.538 <ipython-input-14-5bd60ebc15df>:1(join_on_column_threaded)
#         1    0.000    0.000    0.000    0.000 <ipython-input-14-5bd60ebc15df>:14(<listcomp>)
#         2    0.000    0.000   11.565    5.783 <ipython-input-7-81de4cfdaee6>:1(split_table_into_buckets_threaded)
#         2    0.000    0.000    0.000    0.000 <ipython-input-7-81de4cfdaee6>:13(<listcomp>)
#         2    0.000    0.000    0.000    0.000 <ipython-input-7-81de4cfdaee6>:4(<listcomp>)
#         2    0.000    0.000    3.551    1.776 <ipython-input-7-81de4cfdaee6>:9(merge_buckets_threaded)
#         1    0.000    0.000   15.538   15.538 <string>:1(<module>)
#        35    0.000    0.000    0.000    0.000 _weakrefset.py:38(_remove)
#        35    0.000    0.000    0.000    0.000 _weakrefset.py:81(add)
#        20    0.000    0.000    0.000    0.000 connection.py:117(__init__)
#        20    0.000    0.000    0.000    0.000 connection.py:130(__del__)
#         5    0.000    0.000    0.000    0.000 connection.py:134(_check_closed)
#         5    0.000    0.000    0.000    0.000 connection.py:142(_check_writable)
#         5    0.000    0.000    0.000    0.000 connection.py:181(send_bytes)
#        20    0.000    0.000    0.000    0.000 connection.py:360(_close)
#         5    0.000    0.000    0.000    0.000 connection.py:365(_send)
#         5    0.000    0.000    0.000    0.000 connection.py:390(_send_bytes)
#        10    0.000    0.000    0.000    0.000 connection.py:501(Pipe)
#        10    0.000    0.000    0.004    0.000 context.py:109(SimpleQueue)
#         5    0.000    0.000    0.072    0.014 context.py:114(Pool)
#        30    0.000    0.000    0.000    0.000 context.py:186(get_context)
#        20    0.000    0.000    0.000    0.000 context.py:196(get_start_method)
#         5    0.000    0.000    0.000    0.000 context.py:232(get_context)
#        20    0.001    0.000    0.057    0.003 context.py:274(_Popen)
#        20    0.000    0.000    0.003    0.000 context.py:64(Lock)
#        80    0.002    0.000    0.005    0.000 iostream.py:180(schedule)
#        40    0.001    0.000    0.017    0.000 iostream.py:311(flush)
#        80    0.000    0.000    0.000    0.000 iostream.py:87(_event_pipe)
#        20    0.000    0.000    0.002    0.000 pool.py:150(Process)
#         5    0.001    0.000    0.072    0.014 pool.py:153(__init__)
#         5    0.001    0.000    0.061    0.012 pool.py:225(_repopulate_pool)
#         5    0.000    0.000    0.004    0.001 pool.py:248(_setup_queues)
#         5    0.000    0.000   15.191    3.038 pool.py:268(starmap)
#         5    0.000    0.000    0.001    0.000 pool.py:368(_map_async)
#         5    0.000    0.000    0.273    0.055 pool.py:537(terminate)
#         5    0.000    0.000    0.243    0.049 pool.py:552(_help_stuff_finish)
#         5    0.000    0.000    0.273    0.055 pool.py:561(_terminate_pool)
#         5    0.000    0.000    0.000    0.000 pool.py:607(__enter__)
#         5    0.000    0.000    0.273    0.055 pool.py:610(__exit__)
#         5    0.000    0.000    0.000    0.000 pool.py:619(__init__)
#         5    0.000    0.000    0.000    0.000 pool.py:627(ready)
#         5    0.000    0.000   15.190    3.038 pool.py:634(wait)
#         5    0.000    0.000   15.190    3.038 pool.py:637(get)
#         5    0.000    0.000    0.000    0.000 pool.py:663(__init__)
#        20    0.001    0.000    0.055    0.003 popen_fork.py:16(__init__)
#        78    0.000    0.000    0.028    0.000 popen_fork.py:25(poll)
#         8    0.000    0.000    0.028    0.003 popen_fork.py:44(wait)
#        20    0.000    0.000    0.000    0.000 popen_fork.py:54(terminate)
#        20    0.002    0.000    0.037    0.002 popen_fork.py:64(_launch)
#        20    0.000    0.000    0.000    0.000 process.py:112(terminate)
#         8    0.000    0.000    0.028    0.003 process.py:118(join)
#        20    0.000    0.000    0.000    0.000 process.py:128(is_alive)
#        20    0.000    0.000    0.000    0.000 process.py:146(name)
#        20    0.000    0.000    0.000    0.000 process.py:150(name)
#        20    0.000    0.000    0.000    0.000 process.py:162(daemon)
#        20    0.000    0.000    0.000    0.000 process.py:181(exitcode)
#         8    0.000    0.000    0.000    0.000 process.py:190(ident)
#        20    0.000    0.000    0.000    0.000 process.py:35(current_process)
#        20    0.000    0.000    0.000    0.000 process.py:52(_cleanup)
#        20    0.001    0.000    0.001    0.000 process.py:71(__init__)
#        40    0.000    0.000    0.000    0.000 process.py:83(<genexpr>)
#        20    0.001    0.000    0.058    0.003 process.py:95(start)
#         5    0.000    0.000    0.000    0.000 queue.py:115(put)
#         5    0.000    0.000    0.000    0.000 queue.py:199(_init)
#         5    0.000    0.000    0.000    0.000 queue.py:206(_put)
#         5    0.000    0.000    0.000    0.000 queue.py:27(__init__)
#        10    0.000    0.000    0.004    0.000 queues.py:313(__init__)
#         5    0.000    0.000    0.001    0.000 queues.py:339(put)
#       160    0.000    0.000    0.001    0.000 random.py:222(_randbelow)
#       160    0.000    0.000    0.001    0.000 random.py:252(choice)
#         5    0.000    0.000    0.000    0.000 reduction.py:38(__init__)
#         5    0.000    0.000    0.000    0.000 reduction.py:48(dumps)
#        20    0.000    0.000    0.001    0.000 synchronize.py:115(_make_name)
#        20    0.000    0.000    0.003    0.000 synchronize.py:162(__init__)
#        20    0.001    0.000    0.003    0.000 synchronize.py:51(__init__)
#        20    0.000    0.000    0.000    0.000 synchronize.py:91(_make_methods)
#         5    0.000    0.000    0.000    0.000 synchronize.py:95(__enter__)
#         5    0.000    0.000    0.000    0.000 synchronize.py:98(__exit__)
#        20    0.000    0.000    0.000    0.000 tempfile.py:285(rng)
#        20    0.000    0.000    0.001    0.000 tempfile.py:296(__next__)
#        20    0.000    0.000    0.001    0.000 tempfile.py:299(<listcomp>)
#        15    0.000    0.000    0.000    0.000 threading.py:1024(join)
#       145    0.000    0.000    0.000    0.000 threading.py:1062(_wait_for_tstate_lock)
#       130    0.001    0.000    0.001    0.000 threading.py:1104(is_alive)
#        15    0.000    0.000    0.000    0.000 threading.py:1120(daemon)
#        15    0.000    0.000    0.000    0.000 threading.py:1136(daemon)
#        45    0.000    0.000    0.000    0.000 threading.py:1230(current_thread)
#        75    0.001    0.000    0.001    0.000 threading.py:215(__init__)
#        65    0.000    0.000    0.000    0.000 threading.py:239(__enter__)
#        65    0.000    0.000    0.000    0.000 threading.py:242(__exit__)
#        60    0.000    0.000    0.000    0.000 threading.py:248(_release_save)
#        60    0.000    0.000    0.000    0.000 threading.py:251(_acquire_restore)
#        65    0.000    0.000    0.000    0.000 threading.py:254(_is_owned)
#        60    0.001    0.000   15.204    0.253 threading.py:263(wait)
#         5    0.000    0.000    0.000    0.000 threading.py:334(notify)
#        60    0.000    0.000    0.002    0.000 threading.py:498(__init__)
#       180    0.000    0.000    0.000    0.000 threading.py:506(is_set)
#        60    0.001    0.000   15.204    0.253 threading.py:533(wait)
#        15    0.000    0.000    0.000    0.000 threading.py:727(_newname)
#        15    0.001    0.000    0.001    0.000 threading.py:757(__init__)
#        15    0.000    0.000    0.005    0.000 threading.py:828(start)
#        15    0.000    0.000    0.000    0.000 threading.py:966(_stop)
#        20    0.000    0.000    0.000    0.000 util.py:136(register_after_fork)
#        25    0.001    0.000    0.001    0.000 util.py:151(__init__)
#        25    0.000    0.000    0.273    0.011 util.py:167(__call__)
#        25    0.000    0.000    0.000    0.000 util.py:44(sub_debug)
#        93    0.000    0.000    0.000    0.000 util.py:48(debug)
#        20    0.000    0.000    0.000    0.000 weakref.py:109(remove)
#        20    0.000    0.000    0.000    0.000 weakref.py:165(__setitem__)
#        20    0.000    0.000    0.000    0.000 weakref.py:334(__new__)
#        20    0.000    0.000    0.000    0.000 weakref.py:339(__init__)
#        20    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x9e3d20}
#         5    0.000    0.000    0.000    0.000 {built-in method _struct.pack}
#       125    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#        45    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#        15    0.001    0.000    0.001    0.000 {built-in method _thread.start_new_thread}
#        20    0.000    0.000    0.000    0.000 {built-in method _weakref._remove_dead_weakref}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#         1    0.000    0.000   15.538   15.538 {built-in method builtins.exec}
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        70    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#       210    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#        90    0.000    0.000    0.001    0.000 {built-in method builtins.next}
#        20    0.000    0.000    0.000    0.000 {built-in method posix.WEXITSTATUS}
#        20    0.000    0.000    0.000    0.000 {built-in method posix.WIFEXITED}
#        20    0.000    0.000    0.000    0.000 {built-in method posix.WIFSIGNALED}
#        60    0.000    0.000    0.000    0.000 {built-in method posix.close}
#        20    0.034    0.002    0.034    0.002 {built-in method posix.fork}
#       138    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#        20    0.000    0.000    0.000    0.000 {built-in method posix.kill}
#        30    0.000    0.000    0.000    0.000 {built-in method posix.pipe}
#        80    0.002    0.000    0.002    0.000 {built-in method posix.urandom}
#        78    0.028    0.000    0.028    0.000 {built-in method posix.waitpid}
#         5    0.000    0.000    0.000    0.000 {built-in method posix.write}
#         5    0.000    0.000    0.000    0.000 {method '__enter__' of '_multiprocessing.SemLock' objects}
#        65    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         5    0.000    0.000    0.000    0.000 {method '__exit__' of '_multiprocessing.SemLock' objects}
#        65    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         5    0.243    0.049    0.243    0.049 {method 'acquire' of '_multiprocessing.SemLock' objects}
#       380   15.203    0.040   15.203    0.040 {method 'acquire' of '_thread.lock' objects}
#        55    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#        65    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        20    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#       160    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#        25    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        55    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#         5    0.000    0.000    0.000    0.000 {method 'dump' of '_pickle.Pickler' objects}
#        20    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         5    0.000    0.000    0.000    0.000 {method 'getbuffer' of '_io.BytesIO' objects}
#       267    0.000    0.000    0.000    0.000 {method 'getrandbits' of '_random.Random' objects}
#        40    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#        15    0.000    0.000    0.000    0.000 {method 'locked' of '_thread.lock' objects}
#        80    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         5    0.000    0.000    0.000    0.000 {method 'remove' of 'collections.deque' objects}
#        20    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#        55    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}

# %%
# Using 6 threads
cProfile.run(exec_template.format(num_chunks=NUM_CHUNKS, num_buckets=NUM_BUCKETS, num_threads=6))
# Out:
#          7110 function calls in 10.764 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        65    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:416(parent)
#        65    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:997(_handle_fromlist)
#         1    0.001    0.001   10.763   10.763 <ipython-input-14-5bd60ebc15df>:1(join_on_column_threaded)
#         1    0.000    0.000    0.000    0.000 <ipython-input-14-5bd60ebc15df>:14(<listcomp>)
#         2    0.000    0.000    7.979    3.989 <ipython-input-7-81de4cfdaee6>:1(split_table_into_buckets_threaded)
#         2    0.000    0.000    0.000    0.000 <ipython-input-7-81de4cfdaee6>:13(<listcomp>)
#         2    0.000    0.000    0.000    0.000 <ipython-input-7-81de4cfdaee6>:4(<listcomp>)
#         2    0.000    0.000    2.456    1.228 <ipython-input-7-81de4cfdaee6>:9(merge_buckets_threaded)
#         1    0.000    0.000   10.764   10.764 <string>:1(<module>)
#        45    0.000    0.000    0.000    0.000 _weakrefset.py:38(_remove)
#        45    0.000    0.000    0.000    0.000 _weakrefset.py:81(add)
#        20    0.000    0.000    0.000    0.000 connection.py:117(__init__)
#        20    0.000    0.000    0.000    0.000 connection.py:130(__del__)
#         5    0.000    0.000    0.000    0.000 connection.py:134(_check_closed)
#         5    0.000    0.000    0.000    0.000 connection.py:142(_check_writable)
#         5    0.000    0.000    0.000    0.000 connection.py:181(send_bytes)
#        20    0.000    0.000    0.000    0.000 connection.py:360(_close)
#         5    0.000    0.000    0.000    0.000 connection.py:365(_send)
#         5    0.000    0.000    0.000    0.000 connection.py:390(_send_bytes)
#        10    0.000    0.000    0.000    0.000 connection.py:501(Pipe)
#        10    0.000    0.000    0.005    0.000 context.py:109(SimpleQueue)
#         5    0.000    0.000    0.101    0.020 context.py:114(Pool)
#        30    0.000    0.000    0.000    0.000 context.py:186(get_context)
#        20    0.000    0.000    0.000    0.000 context.py:196(get_start_method)
#         5    0.000    0.000    0.000    0.000 context.py:232(get_context)
#        30    0.001    0.000    0.083    0.003 context.py:274(_Popen)
#        20    0.000    0.000    0.004    0.000 context.py:64(Lock)
#       120    0.003    0.000    0.006    0.000 iostream.py:180(schedule)
#        60    0.001    0.000    0.027    0.000 iostream.py:311(flush)
#       120    0.000    0.000    0.000    0.000 iostream.py:87(_event_pipe)
#        30    0.000    0.000    0.003    0.000 pool.py:150(Process)
#         5    0.001    0.000    0.101    0.020 pool.py:153(__init__)
#         5    0.002    0.000    0.091    0.018 pool.py:225(_repopulate_pool)
#         5    0.000    0.000    0.005    0.001 pool.py:248(_setup_queues)
#         5    0.000    0.000   10.362    2.072 pool.py:268(starmap)
#         5    0.000    0.000    0.000    0.000 pool.py:368(_map_async)
#         5    0.000    0.000    0.298    0.060 pool.py:537(terminate)
#         5    0.000    0.000    0.261    0.052 pool.py:552(_help_stuff_finish)
#         5    0.001    0.000    0.298    0.060 pool.py:561(_terminate_pool)
#         5    0.000    0.000    0.000    0.000 pool.py:607(__enter__)
#         5    0.000    0.000    0.298    0.060 pool.py:610(__exit__)
#         5    0.000    0.000    0.000    0.000 pool.py:619(__init__)
#         5    0.000    0.000    0.000    0.000 pool.py:627(ready)
#         5    0.000    0.000   10.362    2.072 pool.py:634(wait)
#         5    0.000    0.000   10.362    2.072 pool.py:637(get)
#         5    0.000    0.000    0.000    0.000 pool.py:663(__init__)
#        30    0.001    0.000    0.082    0.003 popen_fork.py:16(__init__)
#       151    0.001    0.000    0.035    0.000 popen_fork.py:25(poll)
#        16    0.000    0.000    0.034    0.002 popen_fork.py:44(wait)
#        30    0.000    0.000    0.000    0.000 popen_fork.py:54(terminate)
#        30    0.002    0.000    0.054    0.002 popen_fork.py:64(_launch)
#        30    0.000    0.000    0.000    0.000 process.py:112(terminate)
#        16    0.000    0.000    0.034    0.002 process.py:118(join)
#        30    0.000    0.000    0.000    0.000 process.py:128(is_alive)
#        30    0.000    0.000    0.000    0.000 process.py:146(name)
#        30    0.000    0.000    0.000    0.000 process.py:150(name)
#        30    0.000    0.000    0.000    0.000 process.py:162(daemon)
#        30    0.000    0.000    0.000    0.000 process.py:181(exitcode)
#        16    0.000    0.000    0.000    0.000 process.py:190(ident)
#        20    0.000    0.000    0.000    0.000 process.py:35(current_process)
#        30    0.000    0.000    0.001    0.000 process.py:52(_cleanup)
#        30    0.002    0.000    0.002    0.000 process.py:71(__init__)
#        60    0.000    0.000    0.000    0.000 process.py:83(<genexpr>)
#        30    0.001    0.000    0.086    0.003 process.py:95(start)
#         5    0.000    0.000    0.000    0.000 queue.py:115(put)
#         5    0.000    0.000    0.000    0.000 queue.py:199(_init)
#         5    0.000    0.000    0.000    0.000 queue.py:206(_put)
#         5    0.000    0.000    0.000    0.000 queue.py:27(__init__)
#        10    0.000    0.000    0.005    0.000 queues.py:313(__init__)
#         5    0.000    0.000    0.001    0.000 queues.py:339(put)
#       160    0.000    0.000    0.001    0.000 random.py:222(_randbelow)
#       160    0.000    0.000    0.001    0.000 random.py:252(choice)
#         5    0.000    0.000    0.000    0.000 reduction.py:38(__init__)
#         5    0.000    0.000    0.000    0.000 reduction.py:48(dumps)
#        20    0.000    0.000    0.002    0.000 synchronize.py:115(_make_name)
#        20    0.000    0.000    0.004    0.000 synchronize.py:162(__init__)
#        20    0.001    0.000    0.004    0.000 synchronize.py:51(__init__)
#        20    0.000    0.000    0.000    0.000 synchronize.py:91(_make_methods)
#         5    0.000    0.000    0.000    0.000 synchronize.py:95(__enter__)
#         5    0.000    0.000    0.000    0.000 synchronize.py:98(__exit__)
#        20    0.000    0.000    0.000    0.000 tempfile.py:285(rng)
#        20    0.000    0.000    0.001    0.000 tempfile.py:296(__next__)
#        20    0.000    0.000    0.001    0.000 tempfile.py:299(<listcomp>)
#        15    0.000    0.000    0.000    0.000 threading.py:1024(join)
#       205    0.000    0.000    0.001    0.000 threading.py:1062(_wait_for_tstate_lock)
#       190    0.001    0.000    0.001    0.000 threading.py:1104(is_alive)
#        15    0.000    0.000    0.000    0.000 threading.py:1120(daemon)
#        15    0.000    0.000    0.000    0.000 threading.py:1136(daemon)
#        45    0.000    0.000    0.000    0.000 threading.py:1230(current_thread)
#        95    0.001    0.000    0.001    0.000 threading.py:215(__init__)
#        85    0.000    0.000    0.000    0.000 threading.py:239(__enter__)
#        85    0.000    0.000    0.000    0.000 threading.py:242(__exit__)
#        80    0.000    0.000    0.000    0.000 threading.py:248(_release_save)
#        80    0.000    0.000    0.000    0.000 threading.py:251(_acquire_restore)
#        85    0.000    0.000    0.000    0.000 threading.py:254(_is_owned)
#        80    0.001    0.000   10.382    0.130 threading.py:263(wait)
#         5    0.000    0.000    0.000    0.000 threading.py:334(notify)
#        80    0.001    0.000    0.002    0.000 threading.py:498(__init__)
#       240    0.000    0.000    0.000    0.000 threading.py:506(is_set)
#        80    0.001    0.000   10.383    0.130 threading.py:533(wait)
#        15    0.000    0.000    0.000    0.000 threading.py:727(_newname)
#        15    0.000    0.000    0.001    0.000 threading.py:757(__init__)
#        15    0.000    0.000    0.004    0.000 threading.py:828(start)
#        15    0.000    0.000    0.000    0.000 threading.py:966(_stop)
#        20    0.000    0.000    0.000    0.000 util.py:136(register_after_fork)
#        35    0.001    0.000    0.001    0.000 util.py:151(__init__)
#        35    0.000    0.000    0.298    0.009 util.py:167(__call__)
#        35    0.000    0.000    0.000    0.000 util.py:44(sub_debug)
#       111    0.000    0.000    0.000    0.000 util.py:48(debug)
#        20    0.000    0.000    0.000    0.000 weakref.py:109(remove)
#        20    0.000    0.000    0.000    0.000 weakref.py:165(__setitem__)
#        20    0.000    0.000    0.000    0.000 weakref.py:334(__new__)
#        20    0.000    0.000    0.000    0.000 weakref.py:339(__init__)
#        20    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x9e3d20}
#         5    0.000    0.000    0.000    0.000 {built-in method _struct.pack}
#       165    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#        45    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#        15    0.000    0.000    0.000    0.000 {built-in method _thread.start_new_thread}
#        20    0.000    0.000    0.000    0.000 {built-in method _weakref._remove_dead_weakref}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#         1    0.000    0.000   10.764   10.764 {built-in method builtins.exec}
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        80    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#        30    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#       210    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#       110    0.000    0.000    0.002    0.000 {built-in method builtins.next}
#        29    0.000    0.000    0.000    0.000 {built-in method posix.WEXITSTATUS}
#        29    0.000    0.000    0.000    0.000 {built-in method posix.WIFEXITED}
#        30    0.000    0.000    0.000    0.000 {built-in method posix.WIFSIGNALED}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.WTERMSIG}
#        80    0.000    0.000    0.000    0.000 {built-in method posix.close}
#        30    0.049    0.002    0.049    0.002 {built-in method posix.fork}
#       196    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#        30    0.000    0.000    0.000    0.000 {built-in method posix.kill}
#        40    0.001    0.000    0.001    0.000 {built-in method posix.pipe}
#       120    0.002    0.000    0.002    0.000 {built-in method posix.urandom}
#       151    0.034    0.000    0.034    0.000 {built-in method posix.waitpid}
#         5    0.000    0.000    0.000    0.000 {built-in method posix.write}
#         5    0.000    0.000    0.000    0.000 {method '__enter__' of '_multiprocessing.SemLock' objects}
#        85    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         5    0.000    0.000    0.000    0.000 {method '__exit__' of '_multiprocessing.SemLock' objects}
#        85    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         5    0.261    0.052    0.261    0.052 {method 'acquire' of '_multiprocessing.SemLock' objects}
#       520   10.381    0.020   10.381    0.020 {method 'acquire' of '_thread.lock' objects}
#        75    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#        85    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        30    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#       160    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#        35    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        75    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#         5    0.000    0.000    0.000    0.000 {method 'dump' of '_pickle.Pickler' objects}
#        30    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         5    0.000    0.000    0.000    0.000 {method 'getbuffer' of '_io.BytesIO' objects}
#       281    0.000    0.000    0.000    0.000 {method 'getrandbits' of '_random.Random' objects}
#        50    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#        15    0.000    0.000    0.000    0.000 {method 'locked' of '_thread.lock' objects}
#       100    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         5    0.000    0.000    0.000    0.000 {method 'remove' of 'collections.deque' objects}
#        30    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#        65    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}

# %%
# Using 8 threads
cProfile.run(exec_template.format(num_chunks=NUM_CHUNKS, num_buckets=NUM_BUCKETS, num_threads=8))
# Out:
#          8461 function calls in 9.290 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        75    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:416(parent)
#        75    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:997(_handle_fromlist)
#         1    0.001    0.001    9.290    9.290 <ipython-input-14-5bd60ebc15df>:1(join_on_column_threaded)
#         1    0.000    0.000    0.000    0.000 <ipython-input-14-5bd60ebc15df>:14(<listcomp>)
#         2    0.000    0.000    6.688    3.344 <ipython-input-7-81de4cfdaee6>:1(split_table_into_buckets_threaded)
#         2    0.000    0.000    0.000    0.000 <ipython-input-7-81de4cfdaee6>:13(<listcomp>)
#         2    0.000    0.000    0.000    0.000 <ipython-input-7-81de4cfdaee6>:4(<listcomp>)
#         2    0.000    0.000    2.265    1.133 <ipython-input-7-81de4cfdaee6>:9(merge_buckets_threaded)
#         1    0.000    0.000    9.290    9.290 <string>:1(<module>)
#        55    0.000    0.000    0.000    0.000 _weakrefset.py:38(_remove)
#        55    0.000    0.000    0.000    0.000 _weakrefset.py:81(add)
#        20    0.000    0.000    0.000    0.000 connection.py:117(__init__)
#        20    0.000    0.000    0.000    0.000 connection.py:130(__del__)
#         5    0.000    0.000    0.000    0.000 connection.py:134(_check_closed)
#         5    0.000    0.000    0.000    0.000 connection.py:142(_check_writable)
#         5    0.000    0.000    0.000    0.000 connection.py:181(send_bytes)
#        20    0.000    0.000    0.000    0.000 connection.py:360(_close)
#         5    0.000    0.000    0.000    0.000 connection.py:365(_send)
#         5    0.000    0.000    0.000    0.000 connection.py:390(_send_bytes)
#        10    0.000    0.000    0.000    0.000 connection.py:501(Pipe)
#        10    0.000    0.000    0.004    0.000 context.py:109(SimpleQueue)
#         5    0.000    0.000    0.119    0.024 context.py:114(Pool)
#        30    0.000    0.000    0.000    0.000 context.py:186(get_context)
#        20    0.000    0.000    0.000    0.000 context.py:196(get_start_method)
#         5    0.000    0.000    0.000    0.000 context.py:232(get_context)
#        40    0.002    0.000    0.101    0.003 context.py:274(_Popen)
#        20    0.000    0.000    0.003    0.000 context.py:64(Lock)
#       160    0.004    0.000    0.008    0.000 iostream.py:180(schedule)
#        80    0.002    0.000    0.033    0.000 iostream.py:311(flush)
#       160    0.000    0.000    0.000    0.000 iostream.py:87(_event_pipe)
#        40    0.000    0.000    0.003    0.000 pool.py:150(Process)
#         5    0.001    0.000    0.119    0.024 pool.py:153(__init__)
#         5    0.002    0.000    0.110    0.022 pool.py:225(_repopulate_pool)
#         5    0.000    0.000    0.004    0.001 pool.py:248(_setup_queues)
#         5    0.000    0.000    8.814    1.763 pool.py:268(starmap)
#         5    0.000    0.000    0.000    0.000 pool.py:368(_map_async)
#         5    0.000    0.000    0.355    0.071 pool.py:537(terminate)
#         5    0.000    0.000    0.310    0.062 pool.py:552(_help_stuff_finish)
#         5    0.001    0.000    0.354    0.071 pool.py:561(_terminate_pool)
#         5    0.000    0.000    0.000    0.000 pool.py:607(__enter__)
#         5    0.000    0.000    0.355    0.071 pool.py:610(__exit__)
#         5    0.000    0.000    0.000    0.000 pool.py:619(__init__)
#         5    0.000    0.000    0.000    0.000 pool.py:627(ready)
#         5    0.000    0.000    8.814    1.763 pool.py:634(wait)
#         5    0.000    0.000    8.814    1.763 pool.py:637(get)
#         5    0.000    0.000    0.000    0.000 pool.py:663(__init__)
#        40    0.001    0.000    0.099    0.002 popen_fork.py:16(__init__)
#       228    0.001    0.000    0.043    0.000 popen_fork.py:25(poll)
#         8    0.000    0.000    0.042    0.005 popen_fork.py:44(wait)
#        40    0.000    0.000    0.000    0.000 popen_fork.py:54(terminate)
#        40    0.003    0.000    0.065    0.002 popen_fork.py:64(_launch)
#        40    0.000    0.000    0.000    0.000 process.py:112(terminate)
#         8    0.000    0.000    0.042    0.005 process.py:118(join)
#        40    0.000    0.000    0.001    0.000 process.py:128(is_alive)
#        40    0.000    0.000    0.000    0.000 process.py:146(name)
#        40    0.000    0.000    0.000    0.000 process.py:150(name)
#        40    0.000    0.000    0.000    0.000 process.py:162(daemon)
#        40    0.000    0.000    0.000    0.000 process.py:181(exitcode)
#         8    0.000    0.000    0.000    0.000 process.py:190(ident)
#        20    0.000    0.000    0.000    0.000 process.py:35(current_process)
#        40    0.001    0.000    0.001    0.000 process.py:52(_cleanup)
#        40    0.002    0.000    0.003    0.000 process.py:71(__init__)
#        80    0.000    0.000    0.000    0.000 process.py:83(<genexpr>)
#        40    0.002    0.000    0.104    0.003 process.py:95(start)
#         5    0.000    0.000    0.000    0.000 queue.py:115(put)
#         5    0.000    0.000    0.000    0.000 queue.py:199(_init)
#         5    0.000    0.000    0.000    0.000 queue.py:206(_put)
#         5    0.000    0.000    0.000    0.000 queue.py:27(__init__)
#        10    0.000    0.000    0.004    0.000 queues.py:313(__init__)
#         5    0.000    0.000    0.001    0.000 queues.py:339(put)
#       160    0.000    0.000    0.000    0.000 random.py:222(_randbelow)
#       160    0.000    0.000    0.001    0.000 random.py:252(choice)
#         5    0.000    0.000    0.000    0.000 reduction.py:38(__init__)
#         5    0.000    0.000    0.000    0.000 reduction.py:48(dumps)
#        20    0.000    0.000    0.001    0.000 synchronize.py:115(_make_name)
#        20    0.000    0.000    0.003    0.000 synchronize.py:162(__init__)
#        20    0.001    0.000    0.003    0.000 synchronize.py:51(__init__)
#        20    0.000    0.000    0.000    0.000 synchronize.py:91(_make_methods)
#         5    0.000    0.000    0.000    0.000 synchronize.py:95(__enter__)
#         5    0.000    0.000    0.000    0.000 synchronize.py:98(__exit__)
#        20    0.000    0.000    0.000    0.000 tempfile.py:285(rng)
#        20    0.000    0.000    0.001    0.000 tempfile.py:296(__next__)
#        20    0.000    0.000    0.001    0.000 tempfile.py:299(<listcomp>)
#        15    0.000    0.000    0.000    0.000 threading.py:1024(join)
#       265    0.000    0.000    0.001    0.000 threading.py:1062(_wait_for_tstate_lock)
#       250    0.001    0.000    0.002    0.000 threading.py:1104(is_alive)
#        15    0.000    0.000    0.000    0.000 threading.py:1120(daemon)
#        15    0.000    0.000    0.000    0.000 threading.py:1136(daemon)
#        45    0.000    0.000    0.000    0.000 threading.py:1230(current_thread)
#       115    0.001    0.000    0.001    0.000 threading.py:215(__init__)
#       105    0.000    0.000    0.000    0.000 threading.py:239(__enter__)
#       105    0.000    0.000    0.000    0.000 threading.py:242(__exit__)
#       100    0.000    0.000    0.000    0.000 threading.py:248(_release_save)
#       100    0.000    0.000    0.000    0.000 threading.py:251(_acquire_restore)
#       105    0.000    0.000    0.000    0.000 threading.py:254(_is_owned)
#       100    0.001    0.000    8.836    0.088 threading.py:263(wait)
#         5    0.000    0.000    0.000    0.000 threading.py:334(notify)
#       100    0.001    0.000    0.002    0.000 threading.py:498(__init__)
#       300    0.000    0.000    0.000    0.000 threading.py:506(is_set)
#       100    0.001    0.000    8.837    0.088 threading.py:533(wait)
#        15    0.000    0.000    0.000    0.000 threading.py:727(_newname)
#        15    0.000    0.000    0.001    0.000 threading.py:757(__init__)
#        15    0.000    0.000    0.004    0.000 threading.py:828(start)
#        15    0.000    0.000    0.000    0.000 threading.py:966(_stop)
#        20    0.000    0.000    0.000    0.000 util.py:136(register_after_fork)
#        45    0.002    0.000    0.002    0.000 util.py:151(__init__)
#        45    0.000    0.000    0.355    0.008 util.py:167(__call__)
#        45    0.000    0.000    0.000    0.000 util.py:44(sub_debug)
#       113    0.000    0.000    0.000    0.000 util.py:48(debug)
#        20    0.000    0.000    0.000    0.000 weakref.py:109(remove)
#        20    0.000    0.000    0.000    0.000 weakref.py:165(__setitem__)
#        20    0.000    0.000    0.000    0.000 weakref.py:334(__new__)
#        20    0.000    0.000    0.000    0.000 weakref.py:339(__init__)
#        20    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x9e3d20}
#         5    0.000    0.000    0.000    0.000 {built-in method _struct.pack}
#       205    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#        45    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#        15    0.000    0.000    0.000    0.000 {built-in method _thread.start_new_thread}
#        20    0.000    0.000    0.000    0.000 {built-in method _weakref._remove_dead_weakref}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#         1    0.000    0.000    9.290    9.290 {built-in method builtins.exec}
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        90    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#        40    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#       210    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#       130    0.000    0.000    0.001    0.000 {built-in method builtins.next}
#        38    0.000    0.000    0.000    0.000 {built-in method posix.WEXITSTATUS}
#        38    0.000    0.000    0.000    0.000 {built-in method posix.WIFEXITED}
#        40    0.000    0.000    0.000    0.000 {built-in method posix.WIFSIGNALED}
#         2    0.000    0.000    0.000    0.000 {built-in method posix.WTERMSIG}
#       100    0.001    0.000    0.001    0.000 {built-in method posix.close}
#        40    0.060    0.001    0.060    0.001 {built-in method posix.fork}
#       238    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#        40    0.000    0.000    0.000    0.000 {built-in method posix.kill}
#        50    0.000    0.000    0.000    0.000 {built-in method posix.pipe}
#       160    0.003    0.000    0.003    0.000 {built-in method posix.urandom}
#       228    0.042    0.000    0.042    0.000 {built-in method posix.waitpid}
#         5    0.000    0.000    0.000    0.000 {built-in method posix.write}
#         5    0.000    0.000    0.000    0.000 {method '__enter__' of '_multiprocessing.SemLock' objects}
#       105    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         5    0.000    0.000    0.000    0.000 {method '__exit__' of '_multiprocessing.SemLock' objects}
#       105    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         5    0.309    0.062    0.309    0.062 {method 'acquire' of '_multiprocessing.SemLock' objects}
#       660    8.835    0.013    8.835    0.013 {method 'acquire' of '_thread.lock' objects}
#        95    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#       105    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        40    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#       160    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#        45    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        95    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#         5    0.000    0.000    0.000    0.000 {method 'dump' of '_pickle.Pickler' objects}
#        40    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         5    0.000    0.000    0.000    0.000 {method 'getbuffer' of '_io.BytesIO' objects}
#       249    0.000    0.000    0.000    0.000 {method 'getrandbits' of '_random.Random' objects}
#        60    0.000    0.000    0.001    0.000 {method 'join' of 'str' objects}
#        15    0.000    0.000    0.000    0.000 {method 'locked' of '_thread.lock' objects}
#       120    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         5    0.000    0.000    0.000    0.000 {method 'remove' of 'collections.deque' objects}
#        40    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#        75    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
